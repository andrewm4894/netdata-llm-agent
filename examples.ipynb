# %%
from IPython.display import display, Markdown

from netdata_llm_agent import NetdataLLMAgent


def print_md(text):
    display(Markdown(text))


# list of netdata urls to interact with
netdata_urls = [
    'https://localhost:19999/',
    'https://london3.my-netdata.io/', 
    'https://bangalore.my-netdata.io/',
    'https://newyork.my-netdata.io/',
    'https://sanfrancisco.my-netdata.io/',
    'https://singapore.my-netdata.io/',
    'https://toronto.my-netdata.io/',
]

# create agent
agent = NetdataLLMAgent(netdata_urls, model='gpt-4o-mini')
# create agent using anthropic
# agent = NetdataLLMAgent(netdata_urls, model='claude-3-5-sonnet-20241022', platform='anthropic')
# create agent using ollama
# agent = NetdataLLMAgent(netdata_urls, model='llama3.1', platform='ollama')

# chat with the agent
agent.chat('How much disk space is on london?', verbose=True, no_print=False)
# Out:
# ================================ Human Message =================================
#
# How much disk space is on london?
# ================================== Ai Message ==================================
# Tool Calls:
#   get_charts (call_Ail79vhFSkyZeCBCleqC5pTE)
#  Call ID: call_Ail79vhFSkyZeCBCleqC5pTE
#   Args:
#     netdata_host_url: https://london3.my-netdata.io/
# ================================= Tool Message =================================
# Name: get_charts
#
# [
#   [
#     "system.idlejitter",
#     "CPU Idle Jitter (system.idlejitter)"
#   ],
#   [
#     "netdata.statsd_metrics",
#     "Metrics in the netdata statsd database (netdata.statsd_metrics)"
#   ],
#   [
#     "netdata.statsd_useful_metrics",
#     "Useful metrics in the netdata statsd database (netdata.statsd_useful_metrics)"
#   ],
#   [
#     "netdata.statsd_events",
#     "Events processed by the netdata statsd server (netdata.statsd_events)"
#   ],
#   [
#     "netdata.statsd_reads",
#     "Read operations made by the netdata statsd server (netdata.statsd_reads)"
#   ],
#   [
#     "netdata.statsd_bytes",
#     "Bytes read by the netdata statsd server (netdata.statsd_bytes)"
#   ],
#   [
#     "netdata.statsd_packets",
#     "Network packets processed by the netdata statsd server (netdata.statsd_packets)"
#   ],
#   [
#     "netdata.tcp_connects",
#     "statsd server TCP connects and disconnects (netdata.tcp_connects)"
#   ],
#   [
#     "netdata.tcp_connected",
#     "statsd server TCP connected sockets (netdata.tcp_connected)"
#   ],
#   [
#     "netdata.private_charts",
#     "Private metric charts created by the netdata statsd server (netdata.private_charts)"
#   ],
#   [
#     "mount_points.call",
#     "Calls to mount and umount syscalls (mount_points.call)"
#   ],
#   [
#     "mount_points.error",
#     "Errors to mount and umount file systems (mount_points.error)"
#   ],
#   [
#     "netdata.db_samples_collected",
#     "Netdata Time-Series Collected Samples (netdata.db_samples_collected)"
#   ],
#   [
#     "example.random",
#     "Random Numbers Stacked Chart (example.random)"
#   ],
#   [
#     "netdata.clients",
#     "Netdata Web API Clients (netdata.clients)"
#   ],
#   [
#     "example.random2",
#     "A random number (example.random2)"
#   ],
#   [
#     "netdata.requests",
#     "Netdata Web API Requests Received (netdata.requests)"
#   ],
#   [
#     "netdata.response_time",
#     "Netdata Web API Response Time (netdata.response_time)"
#   ],
#   [
#     "netdata.glibc_arenas",
#     "Glibc Memory Arenas (netdata.glibc_arenas)"
#   ],
#   [
#     "netdata.glibc_malloc_info",
#     "Glibc Malloc Info (netdata.glibc_malloc_info)"
#   ],
#   [
#     "netdata.compression_ratio",
#     "Netdata Web API Responses Compression Savings Ratio (netdata.compression_ratio)"
#   ],
#   [
#     "netdata.queries",
#     "Netdata Time-Series DB Queries (netdata.queries)"
#   ],
#   [
#     "netdata.memory_maps",
#     "Netdata Memory Maps (netdata.memory_maps)"
#   ],
#   [
#     "netdata.plugin_chartsd_example",
#     "Execution time for example plugin (netdata.plugin_chartsd_example)"
#   ],
#   [
#     "netdata.memory_maps_limit",
#     "Netdata Memory Maps Limit (netdata.memory_maps_limit)"
#   ],
#   [
#     "netdata.db_samples_read",
#     "Netdata Time-Series DB Samples Read (netdata.db_samples_read)"
#   ],
#   [
#     "netdata.db_points_results",
#     "Netdata Time-Series Points Generated (netdata.db_points_results)"
#   ],
#   [
#     "netdata.network_api",
#     "Netdata Network Traffic (netdata.network_api)"
#   ],
#   [
#     "netdata.ml_models_consulted",
#     "KMeans models used for prediction (netdata.ml_models_consulted)"
#   ],
#   [
#     "netdata.ml_models_streamed",
#     "KMeans models streamed (netdata.ml_models_streamed)"
#   ],
#   [
#     "netdata.ml_memory_used",
#     "ML memory usage (netdata.ml_memory_used)"
#   ],
#   [
#     "netdata.ml_memory_ops",
#     "ML memory operations (netdata.ml_memory_ops)"
#   ],
#   [
#     "netdata.sqlite3_metatada_cache",
#     "Netdata SQLite3 metadata cache (netdata.sqlite3_metatada_cache)"
#   ],
#   [
#     "netdata.sqlite3_context_cache",
#     "Netdata SQLite3 context cache (netdata.sqlite3_context_cache)"
#   ],
#   [
#     "netdata.tier0_gorilla_pages",
#     "Number of gorilla_pages (netdata.tier0_gorilla_pages)"
#   ],
#   [
#     "netdata.tier0_gorilla_efficiency",
#     "DBENGINE Gorilla Compression Efficiency on Tier 0 (netdata.tier0_gorilla_efficiency)"
#   ],
#   [
#     "netdata.heartbeat",
#     "System clock jitter (netdata.heartbeat)"
#   ],
#   [
#     "netdata.dbengine_main_cache_hit_ratio",
#     "Netdata main Cache Hit Ratio (netdata.dbengine_main_cache_hit_ratio)"
#   ],
#   [
#     "netdata.dbengine_main_cache_operations",
#     "Netdata main Cache Operations (netdata.dbengine_main_cache_operations)"
#   ],
#   [
#     "tc.world-out",
#     "Class Usage (tc.world-out)"
#   ],
#   [
#     "tc.world-out_packets",
#     "Class Packets (tc.world-out_packets)"
#   ],
#   [
#     "tc.world-out_dropped",
#     "Class Dropped Packets (tc.world-out_dropped)"
#   ],
#   [
#     "netdata.dbengine_main_cache_memory",
#     "Netdata main Cache Memory (netdata.dbengine_main_cache_memory)"
#   ],
#   [
#     "tc.world-in",
#     "Class Usage (tc.world-in)"
#   ],
#   [
#     "netdata.dbengine_main_hot_page_sizes",
#     "Netdata main Nominal Page Sizes (without overheads) (netdata.dbengine_main_hot_page_sizes)"
#   ],
#   [
#     "tc.world-in_packets",
#     "Class Packets (tc.world-in_packets)"
#   ],
#   [
#     "tc.world-in_dropped",
#     "Class Dropped Packets (tc.world-in_dropped)"
#   ],
#   [
#     "netdata.dbengine_main_dirty_page_sizes",
#     "Netdata main Nominal Page Sizes (without overheads) (netdata.dbengine_main_dirty_page_sizes)"
#   ],
#   [
#     "netdata.dbengine_main_clean_page_sizes",
#     "Netdata main Nominal Page Sizes (without overheads) (netdata.dbengine_main_clean_page_sizes)"
#   ],
#   [
#     "netdata.workers_cpu",
#     "Netdata Workers CPU Utilization (100% = 1 core) (netdata.workers_cpu)"
#   ],
#   [
#     "netdata.spinlock_total_locks",
#     "Netdata Total Spinlock Locks (netdata.spinlock_total_locks)"
#   ],
#   [
#     "netdata.spinlock_total_spins",
#     "Netdata Total Spinlock Spins (netdata.spinlock_total_spins)"
#   ],
#   [
#     "netdata.dbengine_main_target_memory",
#     "Netdata main Target Cache Memory (netdata.dbengine_main_target_memory)"
#   ],
#   [
#     "netdata.dbengine_main_cache_pages",
#     "Netdata main Cache Pages (netdata.dbengine_main_cache_pages)"
#   ],
#   [
#     "netdata.dbengine_main_cache_memory_changes",
#     "Netdata main Cache Memory Changes (netdata.dbengine_main_cache_memory_changes)"
#   ],
#   [
#     "netdata.dbengine_main_cache_memory_migrations",
#     "Netdata main Cache Memory Migrations (netdata.dbengine_main_cache_memory_migrations)"
#   ],
#   [
#     "netdata.dbengine_main_cache_events",
#     "Netdata main Cache Events (netdata.dbengine_main_cache_events)"
#   ],
#   [
#     "netdata.dbengine_main_waste_events",
#     "Netdata main Waste Events (netdata.dbengine_main_waste_events)"
#   ],
#   [
#     "netdata.dbengine_main_cache_workers",
#     "Netdata main Cache Workers (netdata.dbengine_main_cache_workers)"
#   ],
#   [
#     "netdata.dbengine_open_cache_hit_ratio",
#     "Netdata open Cache Hit Ratio (netdata.dbengine_open_cache_hit_ratio)"
#   ],
#   [
#     "netdata.dbengine_open_cache_operations",
#     "Netdata open Cache Operations (netdata.dbengine_open_cache_operations)"
#   ],
#   [
#     "netdata.dbengine_open_cache_memory",
#     "Netdata open Cache Memory (netdata.dbengine_open_cache_memory)"
#   ],
#   [
#     "netdata.dbengine_open_hot_page_sizes",
#     "Netdata open Nominal Page Sizes (without overheads) (netdata.dbengine_open_hot_page_sizes)"
#   ],
#   [
#     "netdata.dbengine_open_dirty_page_sizes",
#     "Netdata open Nominal Page Sizes (without overheads) (netdata.dbengine_open_dirty_page_sizes)"
#   ],
#   [
#     "netdata.dbengine_open_clean_page_sizes",
#     "Netdata open Nominal Page Sizes (without overheads) (netdata.dbengine_open_clean_page_sizes)"
#   ],
#   [
#     "netdata.dbengine_open_target_memory",
#     "Netdata open Target Cache Memory (netdata.dbengine_open_target_memory)"
#   ],
#   [
#     "netdata.dbengine_open_cache_pages",
#     "Netdata open Cache Pages (netdata.dbengine_open_cache_pages)"
#   ],
#   [
#     "netdata.dbengine_open_cache_memory_changes",
#     "Netdata open Cache Memory Changes (netdata.dbengine_open_cache_memory_changes)"
#   ],
#   [
#     "netdata.dbengine_open_cache_memory_migrations",
#     "Netdata open Cache Memory Migrations (netdata.dbengine_open_cache_memory_migrations)"
#   ],
#   [
#     "netdata.dbengine_open_cache_events",
#     "Netdata open Cache Events (netdata.dbengine_open_cache_events)"
#   ],
#   [
#     "netdata.dbengine_open_waste_events",
#     "Netdata open Waste Events (netdata.dbengine_open_waste_events)"
#   ],
#   [
#     "netdata.dbengine_open_cache_workers",
#     "Netdata open Cache Workers (netdata.dbengine_open_cache_workers)"
#   ],
#   [
#     "netdata.dbengine_extent_cache_hit_ratio",
#     "Netdata extent Cache Hit Ratio (netdata.dbengine_extent_cache_hit_ratio)"
#   ],
#   [
#     "netdata.dbengine_extent_cache_operations",
#     "Netdata extent Cache Operations (netdata.dbengine_extent_cache_operations)"
#   ],
#   [
#     "netdata.spinlock_total_spins_per_lock",
#     "Netdata Average Spinlock Spins Per Lock (netdata.spinlock_total_spins_per_lock)"
#   ],
#   [
#     "netdata.dbengine_extent_cache_memory",
#     "Netdata extent Cache Memory (netdata.dbengine_extent_cache_memory)"
#   ],
#   [
#     "netdata.dbengine_extent_hot_page_sizes",
#     "Netdata extent Nominal Page Sizes (without overheads) (netdata.dbengine_extent_hot_page_sizes)"
#   ],
#   [
#     "netdata.dbengine_extent_dirty_page_sizes",
#     "Netdata extent Nominal Page Sizes (without overheads) (netdata.dbengine_extent_dirty_page_sizes)"
#   ],
#   [
#     "netdata.dbengine_extent_clean_page_sizes",
#     "Netdata extent Nominal Page Sizes (without overheads) (netdata.dbengine_extent_clean_page_sizes)"
#   ],
#   [
#     "netdata.dbengine_extent_target_memory",
#     "Netdata extent Target Cache Memory (netdata.dbengine_extent_target_memory)"
#   ],
#   [
#     "netdata.dbengine_extent_cache_pages",
#     "Netdata extent Cache Pages (netdata.dbengine_extent_cache_pages)"
#   ],
#   [
#     "netdata.dbengine_extent_cache_memory_changes",
#     "Netdata extent Cache Memory Changes (netdata.dbengine_extent_cache_memory_changes)"
#   ],
#   [
#     "netdata.dbengine_extent_cache_memory_migrations",
#     "Netdata extent Cache Memory Migrations (netdata.dbengine_extent_cache_memory_migrations)"
#   ],
#   [
#     "netdata.dbengine_extent_cache_events",
#     "Netdata extent Cache Events (netdata.dbengine_extent_cache_events)"
#   ],
#   [
#     "netdata.dbengine_extent_waste_events",
#     "Netdata extent Waste Events (netdata.dbengine_extent_waste_events)"
#   ],
#   [
#     "netdata.dbengine_extent_cache_workers",
#     "Netdata extent Cache Workers (netdata.dbengine_extent_cache_workers)"
#   ],
#   [
#     "netdata.dbengine_memory",
#     "Netdata DB Memory (netdata.dbengine_memory)"
#   ],
#   [
#     "netdata.dbengine_buffers",
#     "Netdata DB Buffers (netdata.dbengine_buffers)"
#   ],
#   [
#     "netdata.dbengine_metrics",
#     "Netdata Metrics in Metrics Registry (netdata.dbengine_metrics)"
#   ],
#   [
#     "netdata.dbengine_metrics_registry_operations",
#     "Netdata Metrics Registry Operations (netdata.dbengine_metrics_registry_operations)"
#   ],
#   [
#     "netdata.dbengine_metrics_registry_references",
#     "Netdata Metrics Registry References (netdata.dbengine_metrics_registry_references)"
#   ],
#   [
#     "netdata.dbengine_cache_hit_ratio",
#     "Netdata Queries Cache Hit Ratio (netdata.dbengine_cache_hit_ratio)"
#   ],
#   [
#     "netdata.dbengine_queries",
#     "Netdata Queries (netdata.dbengine_queries)"
#   ],
#   [
#     "netdata.dbengine_queries_running",
#     "Netdata Queries Running (netdata.dbengine_queries_running)"
#   ],
#   [
#     "netdata.dbengine_query_pages_metadata_source",
#     "Netdata Query Pages Metadata Source (netdata.dbengine_query_pages_metadata_source)"
#   ],
#   [
#     "netdata.dbengine_query_pages_data_source",
#     "Netdata Query Pages to Data Source (netdata.dbengine_query_pages_data_source)"
#   ],
#   [
#     "netdata.dbengine_query_next_page",
#     "Netdata Query Next Page (netdata.dbengine_query_next_page)"
#   ],
#   [
#     "netdata.dbengine_query_next_page_issues",
#     "Netdata Query Next Page Issues (netdata.dbengine_query_next_page_issues)"
#   ],
#   [
#     "netdata.dbengine_query_pages_disk_load",
#     "Netdata Query Pages Loaded from Disk (netdata.dbengine_query_pages_disk_load)"
#   ],
#   [
#     "netdata.dbengine_events",
#     "Netdata Database Events (netdata.dbengine_events)"
#   ],
#   [
#     "netdata.dbengine_prep_timings",
#     "Netdata Query Planning Timings (netdata.dbengine_prep_timings)"
#   ],
#   [
#     "netdata.dbengine_prep_average_timings",
#     "Netdata Query Planning Average Timings (netdata.dbengine_prep_average_timings)"
#   ],
#   [
#     "netdata.dbengine_query_timings",
#     "Netdata Query Timings (netdata.dbengine_query_timings)"
#   ],
#   [
#     "netdata.dbengine_query_timings_average",
#     "Netdata Query Average Timings (netdata.dbengine_query_timings_average)"
#   ],
#   [
#     "netdata.dbengine_compression_ratio",
#     "Netdata DB engine data extents' compression savings ratio (netdata.dbengine_compression_ratio)"
#   ],
#   [
#     "netdata.dbengine_io_throughput",
#     "Netdata DB engine I/O throughput (netdata.dbengine_io_throughput)"
#   ],
#   [
#     "netdata.dbengine_io_operations",
#     "Netdata DB engine I/O operations (netdata.dbengine_io_operations)"
#   ],
#   [
#     "netdata.dbengine_global_errors",
#     "Netdata DB engine errors (netdata.dbengine_global_errors)"
#   ],
#   [
#     "netdata.dbengine_global_file_descriptors",
#     "Netdata DB engine File Descriptors (netdata.dbengine_global_file_descriptors)"
#   ],
#   [
#     "netdata.dbengine_retention_tier0",
#     "dbengine space and time retention (netdata.dbengine_retention_tier0)"
#   ],
#   [
#     "netdata.dbengine_retention_tier1",
#     "dbengine space and time retention (netdata.dbengine_retention_tier1)"
#   ],
#   [
#     "netdata.dbengine_retention_tier2",
#     "dbengine space and time retention (netdata.dbengine_retention_tier2)"
#   ],
#   [
#     "netdata.registry_sessions",
#     "Netdata Registry Sessions (netdata.registry_sessions)"
#   ],
#   [
#     "netdata.registry_entries",
#     "Netdata Registry Entries (netdata.registry_entries)"
#   ],
#   [
#     "netdata.registry_mem",
#     "Netdata Registry Memory (netdata.registry_mem)"
#   ],
#   [
#     "netdata.strings_ops",
#     "Strings operations (netdata.strings_ops)"
#   ],
#   [
#     "netdata.strings_entries",
#     "Strings entries (netdata.strings_entries)"
#   ],
#   [
#     "netdata.strings_memory",
#     "Strings memory (netdata.strings_memory)"
#   ],
#   [
#     "netdata.aral_uuidmap_memory",
#     "Array Allocator Memory Utilization (netdata.aral_uuidmap_memory)"
#   ],
#   [
#     "netdata.aral_uuidmap_utilization",
#     "Array Allocator Memory Utilization (netdata.aral_uuidmap_utilization)"
#   ],
#   [
#     "netdata.aral_judy_memory",
#     "Array Allocator Memory Utilization (netdata.aral_judy_memory)"
#   ],
#   [
#     "netdata.aral_judy_utilization",
#     "Array Allocator Memory Utilization (netdata.aral_judy_utilization)"
#   ],
#   [
#     "netdata.aral_by-size_memory",
#     "Array Allocator Memory Utilization (netdata.aral_by-size_memory)"
#   ],
#   [
#     "netdata.aral_by-size_utilization",
#     "Array Allocator Memory Utilization (netdata.aral_by-size_utilization)"
#   ],
#   [
#     "netdata.aral_pgc_memory",
#     "Array Allocator Memory Utilization (netdata.aral_pgc_memory)"
#   ],
#   [
#     "netdata.aral_pgc_utilization",
#     "Array Allocator Memory Utilization (netdata.aral_pgc_utilization)"
#   ],
#   [
#     "netdata.aral_pgd_memory",
#     "Array Allocator Memory Utilization (netdata.aral_pgd_memory)"
#   ],
#   [
#     "netdata.aral_pgd_utilization",
#     "Array Allocator Memory Utilization (netdata.aral_pgd_utilization)"
#   ],
#   [
#     "netdata.aral_mrg_memory",
#     "Array Allocator Memory Utilization (netdata.aral_mrg_memory)"
#   ],
#   [
#     "netdata.aral_mrg_utilization",
#     "Array Allocator Memory Utilization (netdata.aral_mrg_utilization)"
#   ],
#   [
#     "netdata.aral_pdc_memory",
#     "Array Allocator Memory Utilization (netdata.aral_pdc_memory)"
#   ],
#   [
#     "netdata.aral_pdc_utilization",
#     "Array Allocator Memory Utilization (netdata.aral_pdc_utilization)"
#   ],
#   [
#     "netdata.aral_pd_memory",
#     "Array Allocator Memory Utilization (netdata.aral_pd_memory)"
#   ],
#   [
#     "netdata.aral_pd_utilization",
#     "Array Allocator Memory Utilization (netdata.aral_pd_utilization)"
#   ],
#   [
#     "netdata.aral_epdl_memory",
#     "Array Allocator Memory Utilization (netdata.aral_epdl_memory)"
#   ],
#   [
#     "netdata.aral_epdl_utilization",
#     "Array Allocator Memory Utilization (netdata.aral_epdl_utilization)"
#   ],
#   [
#     "netdata.aral_deol_memory",
#     "Array Allocator Memory Utilization (netdata.aral_deol_memory)"
#   ],
#   [
#     "netdata.aral_deol_utilization",
#     "Array Allocator Memory Utilization (netdata.aral_deol_utilization)"
#   ],
#   [
#     "netdata.aral_opcodes_memory",
#     "Array Allocator Memory Utilization (netdata.aral_opcodes_memory)"
#   ],
#   [
#     "netdata.aral_opcodes_utilization",
#     "Array Allocator Memory Utilization (netdata.aral_opcodes_utilization)"
#   ],
#   [
#     "netdata.aral_workers_memory",
#     "Array Allocator Memory Utilization (netdata.aral_workers_memory)"
#   ],
#   [
#     "netdata.aral_workers_utilization",
#     "Array Allocator Memory Utilization (netdata.aral_workers_utilization)"
#   ],
#   [
#     "netdata.aral_query_handles_memory",
#     "Array Allocator Memory Utilization (netdata.aral_query_handles_memory)"
#   ],
#   [
#     "netdata.aral_query_handles_utilization",
#     "Array Allocator Memory Utilization (netdata.aral_query_handles_utilization)"
#   ],
#   [
#     "netdata.aral_descriptors_memory",
#     "Array Allocator Memory Utilization (netdata.aral_descriptors_memory)"
#   ],
#   [
#     "netdata.aral_descriptors_utilization",
#     "Array Allocator Memory Utilization (netdata.aral_descriptors_utilization)"
#   ],
#   [
#     "netdata.aral_extent_io_memory",
#     "Array Allocator Memory Utilization (netdata.aral_extent_io_memory)"
#   ],
#   [
#     "netdata.aral_extent_io_utilization",
#     "Array Allocator Memory Utilization (netdata.aral_extent_io_utilization)"
#   ],
#   [
#     "netdata.streaming_inbound",
#     "Inbound Nodes (netdata.streaming_inbound)"
#   ],
#   [
#     "netdata.streaming_rejections_inbound",
#     "Inbound Streaming Events (netdata.streaming_rejections_inbound)"
#   ],
#   [
#     "netdata.streaming_disconnects_inbound",
#     "Inbound Streaming Events (netdata.streaming_disconnects_inbound)"
#   ],
#   [
#     "netdata.streaming_outbound",
#     "Outbound Nodes (netdata.streaming_outbound)"
#   ],
#   [
#     "netdata.streaming_info_failed_outbound",
#     "Outbound Streaming Events (netdata.streaming_info_failed_outbound)"
#   ],
#   [
#     "netdata.streaming_rejections_outbound",
#     "Outbound Streaming Events (netdata.streaming_rejections_outbound)"
#   ],
#   [
#     "netdata.streaming_disconnects_outbound",
#     "Outbound Streaming Events (netdata.streaming_disconnects_outbound)"
#   ],
#   [
#     "netdata.server_cpu",
#     "Netdata CPU usage (netdata.server_cpu)"
#   ],
#   [
#     "netdata.uptime",
#     "Netdata uptime (netdata.uptime)"
#   ],
#   [
#     "netdata.memory",
#     "Netdata Memory (netdata.memory)"
#   ],
#   [
#     "netdata.memory_buffers",
#     "Netdata Memory Buffers (netdata.memory_buffers)"
#   ],
#   [
#     "netdata.out_of_memory_protection",
#     "Out of Memory Protection (netdata.out_of_memory_protection)"
#   ],
#   [
#     "netdata.machine_learning_status_on_registry.my-netdata.io",
#     "Machine learning status (netdata.machine_learning_status_on_registry.my-netdata.io)"
#   ],
#   [
#     "netdata.metric_types_on_registry.my-netdata.io",
#     "Dimensions by metric type (netdata.metric_types_on_registry.my-netdata.io)"
#   ],
#   [
#     "netdata.training_status_on_registry.my-netdata.io",
#     "Training status of dimensions (netdata.training_status_on_registry.my-netdata.io)"
#   ],
#   [
#     "anomaly_detection.dimensions_on_registry.my-netdata.io",
#     "Anomaly detection dimensions (anomaly_detection.dimensions_on_registry.my-netdata.io)"
#   ],
#   [
#     "anomaly_detection.ml_running_on_registry.my-netdata.io",
#     "ML running (anomaly_detection.ml_running_on_registry.my-netdata.io)"
#   ],
#   [
#     "anomaly_detection.anomaly_rate_on_registry.my-netdata.io",
#     "Percentage of anomalous dimensions (anomaly_detection.anomaly_rate_on_registry.my-netdata.io)"
#   ],
#   [
#     "anomaly_detection.type_anomaly_rate_on_registry.my-netdata.io",
#     "Percentage of anomalous dimensions by type (anomaly_detection.type_anomaly_rate_on_registry.my-netdata.io)"
#   ],
#   [
#     "anomaly_detection.anomaly_detection_on_registry.my-netdata.io",
#     "Anomaly detection events (anomaly_detection.anomaly_detection_on_registry.my-netdata.io)"
#   ],
#   [
#     "netdata.training_queue_0_ops",
#     "Training queue operations (netdata.training_queue_0_ops)"
#   ],
#   [
#     "netdata.training_queue_0_size",
#     "Training queue size (netdata.training_queue_0_size)"
#   ],
#   [
#     "netdata.training_queue_0_time_stats",
#     "Training time stats (netdata.training_queue_0_time_stats)"
#   ],
#   [
#     "netdata.training_queue_0_results",
#     "Training results (netdata.training_queue_0_results)"
#   ],
#   [
#     "netdata.training_queue_1_ops",
#     "Training queue operations (netdata.training_queue_1_ops)"
#   ],
#   [
#     "netdata.training_queue_1_size",
#     "Training queue size (netdata.training_queue_1_size)"
#   ],
#   [
#     "netdata.training_queue_1_time_stats",
#     "Training time stats (netdata.training_queue_1_time_stats)"
#   ],
#   [
#     "netdata.training_queue_1_results",
#     "Training results (netdata.training_queue_1_results)"
#   ],
#   [
#     "netdata.training_queue_2_ops",
#     "Training queue operations (netdata.training_queue_2_ops)"
#   ],
#   [
#     "netdata.training_queue_2_size",
#     "Training queue size (netdata.training_queue_2_size)"
#   ],
#   [
#     "netdata.training_queue_2_time_stats",
#     "Training time stats (netdata.training_queue_2_time_stats)"
#   ],
#   [
#     "netdata.training_queue_2_results",
#     "Training results (netdata.training_queue_2_results)"
#   ],
#   [
#     "netdata.training_queue_3_ops",
#     "Training queue operations (netdata.training_queue_3_ops)"
#   ],
#   [
#     "netdata.training_queue_3_size",
#     "Training queue size (netdata.training_queue_3_size)"
#   ],
#   [
#     "netdata.training_queue_3_time_stats",
#     "Training time stats (netdata.training_queue_3_time_stats)"
#   ],
#   [
#     "netdata.training_queue_3_results",
#     "Training results (netdata.training_queue_3_results)"
#   ],
#   [
#     "mem.fragmentation_index_node_0_dma",
#     "Memory fragmentation index for each order (mem.fragmentation_index_node_0_dma)"
#   ],
#   [
#     "mem.fragmentation_index_node_0_dma32",
#     "Memory fragmentation index for each order (mem.fragmentation_index_node_0_dma32)"
#   ],
#   [
#     "mem.fragmentation_index_node_0_normal",
#     "Memory fragmentation index for each order (mem.fragmentation_index_node_0_normal)"
#   ],
#   [
#     "net.eth0",
#     "Bandwidth (net.eth0)"
#   ],
#   [
#     "net_speed.eth0",
#     "Interface Speed (net_speed.eth0)"
#   ],
#   [
#     "net_duplex.eth0",
#     "Interface Duplex State (net_duplex.eth0)"
#   ],
#   [
#     "net_operstate.eth0",
#     "Interface Operational State (net_operstate.eth0)"
#   ],
#   [
#     "net_carrier.eth0",
#     "Interface Physical Link State (net_carrier.eth0)"
#   ],
#   [
#     "net_mtu.eth0",
#     "Interface MTU (net_mtu.eth0)"
#   ],
#   [
#     "net_packets.eth0",
#     "Packets (net_packets.eth0)"
#   ],
#   [
#     "net_errors.eth0",
#     "Interface Errors (net_errors.eth0)"
#   ],
#   [
#     "net_drops.eth0",
#     "Interface Drops (net_drops.eth0)"
#   ],
#   [
#     "net_fifo.eth0",
#     "Interface FIFO Buffer Errors (net_fifo.eth0)"
#   ],
#   [
#     "net_events.eth0",
#     "Network Interface Events (net_events.eth0)"
#   ],
#   [
#     "net.vpn0",
#     "Bandwidth (net.vpn0)"
#   ],
#   [
#     "net_operstate.vpn0",
#     "Interface Operational State (net_operstate.vpn0)"
#   ],
#   [
#     "net_carrier.vpn0",
#     "Interface Physical Link State (net_carrier.vpn0)"
#   ],
#   [
#     "net_mtu.vpn0",
#     "Interface MTU (net_mtu.vpn0)"
#   ],
#   [
#     "net_packets.vpn0",
#     "Packets (net_packets.vpn0)"
#   ],
#   [
#     "net_errors.vpn0",
#     "Interface Errors (net_errors.vpn0)"
#   ],
#   [
#     "net_drops.vpn0",
#     "Interface Drops (net_drops.vpn0)"
#   ],
#   [
#     "net_fifo.vpn0",
#     "Interface FIFO Buffer Errors (net_fifo.vpn0)"
#   ],
#   [
#     "net_events.vpn0",
#     "Network Interface Events (net_events.vpn0)"
#   ],
#   [
#     "net.wg0",
#     "Bandwidth (net.wg0)"
#   ],
#   [
#     "net_operstate.wg0",
#     "Interface Operational State (net_operstate.wg0)"
#   ],
#   [
#     "net_carrier.wg0",
#     "Interface Physical Link State (net_carrier.wg0)"
#   ],
#   [
#     "net_mtu.wg0",
#     "Interface MTU (net_mtu.wg0)"
#   ],
#   [
#     "net_packets.wg0",
#     "Packets (net_packets.wg0)"
#   ],
#   [
#     "net_errors.wg0",
#     "Interface Errors (net_errors.wg0)"
#   ],
#   [
#     "net_drops.wg0",
#     "Interface Drops (net_drops.wg0)"
#   ],
#   [
#     "net_fifo.wg0",
#     "Interface FIFO Buffer Errors (net_fifo.wg0)"
#   ],
#   [
#     "net_events.wg0",
#     "Network Interface Events (net_events.wg0)"
#   ],
#   [
#     "system.net",
#     "Physical Network Interfaces Aggregated Bandwidth (system.net)"
#   ],
#   [
#     "disk_space./",
#     "Disk Space Usage (disk_space./)"
#   ],
#   [
#     "disk_inodes./",
#     "Disk Files (inodes) Usage (disk_inodes./)"
#   ],
#   [
#     "disk_space./run",
#     "Disk Space Usage (disk_space./run)"
#   ],
#   [
#     "disk_inodes./run",
#     "Disk Files (inodes) Usage (disk_inodes./run)"
#   ],
#   [
#     "netfilter.netlink_new",
#     "Connection Tracker New Connections (netfilter.netlink_new)"
#   ],
#   [
#     "netfilter.netlink_changes",
#     "Connection Tracker Changes (netfilter.netlink_changes)"
#   ],
#   [
#     "netfilter.netlink_search",
#     "Connection Tracker Searches (netfilter.netlink_search)"
#   ],
#   [
#     "netfilter.netlink_errors",
#     "Connection Tracker Errors (netfilter.netlink_errors)"
#   ],
#   [
#     "netfilter.netlink_expect",
#     "Connection Tracker Expectations (netfilter.netlink_expect)"
#   ],
#   [
#     "system.cpu",
#     "Total CPU utilization (system.cpu)"
#   ],
#   [
#     "system.intr",
#     "CPU Interrupts (system.intr)"
#   ],
#   [
#     "system.ctxt",
#     "CPU Context Switches (system.ctxt)"
#   ],
#   [
#     "system.forks",
#     "Started Processes (system.forks)"
#   ],
#   [
#     "system.processes",
#     "System Processes (system.processes)"
#   ],
#   [
#     "system.uptime",
#     "System Uptime (system.uptime)"
#   ],
#   [
#     "system.load",
#     "System Load Average (system.load)"
#   ],
#   [
#     "system.active_processes",
#     "System Active Processes (system.active_processes)"
#   ],
#   [
#     "system.file_nr_used",
#     "File Descriptors (system.file_nr_used)"
#   ],
#   [
#     "system.file_nr_utilization",
#     "File Descriptors Utilization (system.file_nr_utilization)"
#   ],
#   [
#     "system.entropy",
#     "Available Entropy (system.entropy)"
#   ],
#   [
#     "system.post_update_reboot_status",
#     "Post-Update Reboot Status (system.post_update_reboot_status)"
#   ],
#   [
#     "system.cpu_some_pressure",
#     "CPU some pressure (system.cpu_some_pressure)"
#   ],
#   [
#     "system.cpu_some_pressure_stall_time",
#     "CPU some pressure stall time (system.cpu_some_pressure_stall_time)"
#   ],
#   [
#     "system.memory_some_pressure",
#     "Memory some pressure (system.memory_some_pressure)"
#   ],
#   [
#     "system.memory_some_pressure_stall_time",
#     "Memory some pressure stall time (system.memory_some_pressure_stall_time)"
#   ],
#   [
#     "system.memory_full_pressure",
#     "Memory full pressure (system.memory_full_pressure)"
#   ],
#   [
#     "system.memory_full_pressure_stall_time",
#     "Memory full pressure stall time (system.memory_full_pressure_stall_time)"
#   ],
#   [
#     "system.io_some_pressure",
#     "I/O some pressure (system.io_some_pressure)"
#   ],
#   [
#     "system.io_some_pressure_stall_time",
#     "I/O some pressure stall time (system.io_some_pressure_stall_time)"
#   ],
#   [
#     "system.io_full_pressure",
#     "I/O full pressure (system.io_full_pressure)"
#   ],
#   [
#     "system.io_full_pressure_stall_time",
#     "I/O full pressure stall time (system.io_full_pressure_stall_time)"
#   ],
#   [
#     "system.interrupts",
#     "System interrupts (system.interrupts)"
#   ],
#   [
#     "system.softirqs",
#     "System softirqs (system.softirqs)"
#   ],
#   [
#     "system.pgpgio",
#     "Memory Paged from/to disk (system.pgpgio)"
#   ],
#   [
#     "mem.pgfaults",
#     "Memory Page Faults (mem.pgfaults)"
#   ],
#   [
#     "mem.oom_kill",
#     "Out of Memory Kills (mem.oom_kill)"
#   ],
#   [
#     "mem.balloon",
#     "Memory Ballooning Operations (mem.balloon)"
#   ],
#   [
#     "mem.ksm_cow",
#     "KSM Copy On Write Operations (mem.ksm_cow)"
#   ],
#   [
#     "mem.thp_faults",
#     "Transparent Huge Page Fault Allocations (mem.thp_faults)"
#   ],
#   [
#     "mem.thp_file",
#     "Transparent Huge Page File Allocations (mem.thp_file)"
#   ],
#   [
#     "mem.thp_zero",
#     "Transparent Huge Zero Page Allocations (mem.thp_zero)"
#   ],
#   [
#     "mem.thp_collapse",
#     "Transparent Huge Pages Collapsed by khugepaged (mem.thp_collapse)"
#   ],
#   [
#     "mem.thp_split",
#     "Transparent Huge Page Splits (mem.thp_split)"
#   ],
#   [
#     "mem.thp_swapout",
#     "Transparent Huge Pages Swap Out (mem.thp_swapout)"
#   ],
#   [
#     "mem.thp_compact",
#     "Transparent Huge Pages Compaction (mem.thp_compact)"
#   ],
#   [
#     "system.ram",
#     "System RAM (system.ram)"
#   ],
#   [
#     "mem.available",
#     "Available RAM for applications (mem.available)"
#   ],
#   [
#     "mem.hwcorrupt",
#     "Corrupted Memory, detected by ECC (mem.hwcorrupt)"
#   ],
#   [
#     "mem.committed",
#     "Committed (Allocated) Memory (mem.committed)"
#   ],
#   [
#     "mem.writeback",
#     "Writeback Memory (mem.writeback)"
#   ],
#   [
#     "mem.kernel",
#     "Memory Used by Kernel (mem.kernel)"
#   ],
#   [
#     "mem.slab",
#     "Reclaimable Kernel Memory (mem.slab)"
#   ],
#   [
#     "mem.thp",
#     "Transparent HugePages Memory (mem.thp)"
#   ],
#   [
#     "mem.thp_details",
#     "Details of Transparent HugePages Usage (mem.thp_details)"
#   ],
#   [
#     "mem.reclaiming",
#     "Memory Reclaiming (mem.reclaiming)"
#   ],
#   [
#     "mem.directmaps",
#     "Direct Memory Mappings (mem.directmaps)"
#   ],
#   [
#     "mem.ksm",
#     "Kernel Same Page Merging (mem.ksm)"
#   ],
#   [
#     "mem.ksm_savings",
#     "Kernel Same Page Merging Savings (mem.ksm_savings)"
#   ],
#   [
#     "mem.ksm_ratios",
#     "Kernel Same Page Merging Effectiveness (mem.ksm_ratios)"
#   ],
#   [
#     "ip.sockstat_sockets",
#     "Sockets used for all address families (ip.sockstat_sockets)"
#   ],
#   [
#     "ipv4.sockstat_tcp_sockets",
#     "TCP Sockets (ipv4.sockstat_tcp_sockets)"
#   ],
#   [
#     "ipv4.sockstat_tcp_mem",
#     "TCP Sockets Memory (ipv4.sockstat_tcp_mem)"
#   ],
#   [
#     "ipv4.sockstat_udp_sockets",
#     "IPv4 UDP Sockets (ipv4.sockstat_udp_sockets)"
#   ],
#   [
#     "ipv4.sockstat_udp_mem",
#     "IPv4 UDP Sockets Memory (ipv4.sockstat_udp_mem)"
#   ],
#   [
#     "ipv4.sockstat_udplite_sockets",
#     "IPv4 UDPLITE Sockets (ipv4.sockstat_udplite_sockets)"
#   ],
#   [
#     "ipv4.sockstat_raw_sockets",
#     "IPv4 RAW Sockets (ipv4.sockstat_raw_sockets)"
#   ],
#   [
#     "ipv4.sockstat_frag_sockets",
#     "IPv4 FRAG Sockets (ipv4.sockstat_frag_sockets)"
#   ],
#   [
#     "ipv4.sockstat_frag_mem",
#     "IPv4 FRAG Sockets Memory (ipv4.sockstat_frag_mem)"
#   ],
#   [
#     "ipv6.sockstat6_tcp_sockets",
#     "IPv6 TCP Sockets (ipv6.sockstat6_tcp_sockets)"
#   ],
#   [
#     "ipv6.sockstat6_udp_sockets",
#     "IPv6 UDP Sockets (ipv6.sockstat6_udp_sockets)"
#   ],
#   [
#     "ipv6.sockstat6_udplite_sockets",
#     "IPv6 UDPLITE Sockets (ipv6.sockstat6_udplite_sockets)"
#   ],
#   [
#     "ipv6.sockstat6_raw_sockets",
#     "IPv6 RAW Sockets (ipv6.sockstat6_raw_sockets)"
#   ],
#   [
#     "ipv6.sockstat6_frag_sockets",
#     "IPv6 FRAG Sockets (ipv6.sockstat6_frag_sockets)"
#   ],
#   [
#     "system.ip",
#     "IPv4 Bandwidth (system.ip)"
#   ],
#   [
#     "ipv4.mcast",
#     "IP Multicast Bandwidth (ipv4.mcast)"
#   ],
#   [
#     "ipv4.bcast",
#     "IPv4 Broadcast Bandwidth (ipv4.bcast)"
#   ],
#   [
#     "ipv4.mcastpkts",
#     "IPv4 Multicast Packets (ipv4.mcastpkts)"
#   ],
#   [
#     "ipv4.bcastpkts",
#     "IPv4 Broadcast Packets (ipv4.bcastpkts)"
#   ],
#   [
#     "ipv4.ecnpkts",
#     "IPv4 ECN Statistics (ipv4.ecnpkts)"
#   ],
#   [
#     "ip.tcpmemorypressures",
#     "TCP Memory Pressures (ip.tcpmemorypressures)"
#   ],
#   [
#     "ip.tcpconnaborts",
#     "TCP Connection Aborts (ip.tcpconnaborts)"
#   ],
#   [
#     "ip.tcpreorders",
#     "TCP Reordered Packets by Detection Method (ip.tcpreorders)"
#   ],
#   [
#     "ip.tcpofo",
#     "TCP Out-Of-Order Queue (ip.tcpofo)"
#   ],
#   [
#     "ip.tcpsyncookies",
#     "TCP SYN Cookies (ip.tcpsyncookies)"
#   ],
#   [
#     "ip.tcp_syn_queue",
#     "TCP SYN Queue Issues (ip.tcp_syn_queue)"
#   ],
#   [
#     "ip.tcp_accept_queue",
#     "TCP Accept Queue Issues (ip.tcp_accept_queue)"
#   ],
#   [
#     "ipv4.packets",
#     "IPv4 Packets (ipv4.packets)"
#   ],
#   [
#     "ipv4.fragsout",
#     "IPv4 Fragments Sent (ipv4.fragsout)"
#   ],
#   [
#     "ipv4.fragsin",
#     "IPv4 Fragments Reassembly (ipv4.fragsin)"
#   ],
#   [
#     "ipv4.errors",
#     "IPv4 Errors (ipv4.errors)"
#   ],
#   [
#     "ipv4.icmp",
#     "IPv4 ICMP Packets (ipv4.icmp)"
#   ],
#   [
#     "ipv4.icmp_errors",
#     "IPv4 ICMP Errors (ipv4.icmp_errors)"
#   ],
#   [
#     "ipv4.icmpmsg",
#     "IPv4 ICMP Messages (ipv4.icmpmsg)"
#   ],
#   [
#     "ip.tcpsock",
#     "TCP Connections (ip.tcpsock)"
#   ],
#   [
#     "ip.tcppackets",
#     "IPv4 TCP Packets (ip.tcppackets)"
#   ],
#   [
#     "ip.tcperrors",
#     "IPv4 TCP Errors (ip.tcperrors)"
#   ],
#   [
#     "ip.tcpopens",
#     "IPv4 TCP Opens (ip.tcpopens)"
#   ],
#   [
#     "ip.tcphandshake",
#     "IPv4 TCP Handshake Issues (ip.tcphandshake)"
#   ],
#   [
#     "ipv4.udppackets",
#     "IPv4 UDP Packets (ipv4.udppackets)"
#   ],
#   [
#     "ipv4.udperrors",
#     "IPv4 UDP Errors (ipv4.udperrors)"
#   ],
#   [
#     "ipv4.udplite",
#     "IPv4 UDPLite Packets (ipv4.udplite)"
#   ],
#   [
#     "ipv4.udplite_errors",
#     "IPv4 UDPLite Errors (ipv4.udplite_errors)"
#   ],
#   [
#     "system.ipv6",
#     "IPv6 Bandwidth (system.ipv6)"
#   ],
#   [
#     "ipv6.packets",
#     "IPv6 Packets (ipv6.packets)"
#   ],
#   [
#     "ipv6.fragsout",
#     "IPv6 Fragments Sent (ipv6.fragsout)"
#   ],
#   [
#     "ipv6.fragsin",
#     "IPv6 Fragments Reassembly (ipv6.fragsin)"
#   ],
#   [
#     "ipv6.errors",
#     "IPv6 Errors (ipv6.errors)"
#   ],
#   [
#     "ipv6.udppackets",
#     "IPv6 UDP Packets (ipv6.udppackets)"
#   ],
#   [
#     "ipv6.udperrors",
#     "IPv6 UDP Errors (ipv6.udperrors)"
#   ],
#   [
#     "ipv6.udplitepackets",
#     "IPv6 UDPlite Packets (ipv6.udplitepackets)"
#   ],
#   [
#     "ipv6.udpliteerrors",
#     "IPv6 UDP Lite Errors (ipv6.udpliteerrors)"
#   ],
#   [
#     "ipv6.mcast",
#     "IPv6 Multicast Bandwidth (ipv6.mcast)"
#   ],
#   [
#     "ipv6.bcast",
#     "IPv6 Broadcast Bandwidth (ipv6.bcast)"
#   ],
#   [
#     "ipv6.mcastpkts",
#     "IPv6 Multicast Packets (ipv6.mcastpkts)"
#   ],
#   [
#     "ipv6.icmp",
#     "IPv6 ICMP Messages (ipv6.icmp)"
#   ],
#   [
#     "ipv6.icmpredir",
#     "IPv6 ICMP Redirects (ipv6.icmpredir)"
#   ],
#   [
#     "ipv6.icmperrors",
#     "IPv6 ICMP Errors (ipv6.icmperrors)"
#   ],
#   [
#     "ipv6.icmpechos",
#     "IPv6 ICMP Echo (ipv6.icmpechos)"
#   ],
#   [
#     "ipv6.groupmemb",
#     "IPv6 ICMP Group Membership (ipv6.groupmemb)"
#   ],
#   [
#     "ipv6.icmprouter",
#     "IPv6 Router Messages (ipv6.icmprouter)"
#   ],
#   [
#     "ipv6.icmpneighbor",
#     "IPv6 Neighbor Messages (ipv6.icmpneighbor)"
#   ],
#   [
#     "ipv6.icmpmldv2",
#     "IPv6 ICMP MLDv2 Reports (ipv6.icmpmldv2)"
#   ],
#   [
#     "ipv6.icmptypes",
#     "IPv6 ICMP Types (ipv6.icmptypes)"
#   ],
#   [
#     "ipv6.ect",
#     "IPv6 ECT Packets (ipv6.ect)"
#   ],
#   [
#     "system.softnet_stat",
#     "System softnet_stat (system.softnet_stat)"
#   ],
#   [
#     "netfilter.conntrack_sockets",
#     "Connection Tracker Connections (netfilter.conntrack_sockets)"
#   ],
#   [
#     "netfilter.conntrack_new",
#     "Connection Tracker New Connections (netfilter.conntrack_new)"
#   ],
#   [
#     "netfilter.conntrack_changes",
#     "Connection Tracker Changes (netfilter.conntrack_changes)"
#   ],
#   [
#     "netfilter.conntrack_expect",
#     "Connection Tracker Expectations (netfilter.conntrack_expect)"
#   ],
#   [
#     "netfilter.conntrack_search",
#     "Connection Tracker Searches (netfilter.conntrack_search)"
#   ],
#   [
#     "netfilter.conntrack_errors",
#     "Connection Tracker Errors (netfilter.conntrack_errors)"
#   ],
#   [
#     "netfilter.synproxy_syn_received",
#     "SYNPROXY SYN Packets received (netfilter.synproxy_syn_received)"
#   ],
#   [
#     "netfilter.synproxy_conn_reopened",
#     "SYNPROXY Connections Reopened (netfilter.synproxy_conn_reopened)"
#   ],
#   [
#     "netfilter.synproxy_cookies",
#     "SYNPROXY TCP Cookies (netfilter.synproxy_cookies)"
#   ],
#   [
#     "disk.vda",
#     "Disk I/O Bandwidth (disk.vda)"
#   ],
#   [
#     "disk_ext.vda",
#     "Amount of Discarded Data (disk_ext.vda)"
#   ],
#   [
#     "disk_ops.vda",
#     "Disk Completed I/O Operations (disk_ops.vda)"
#   ],
#   [
#     "disk_ext_ops.vda",
#     "Disk Completed Extended I/O Operations (disk_ext_ops.vda)"
#   ],
#   [
#     "disk_qops.vda",
#     "Disk Current I/O Operations (disk_qops.vda)"
#   ],
#   [
#     "disk_backlog.vda",
#     "Disk Backlog (disk_backlog.vda)"
#   ],
#   [
#     "disk_busy.vda",
#     "Disk Busy Time (disk_busy.vda)"
#   ],
#   [
#     "disk_util.vda",
#     "Disk Utilization Time (disk_util.vda)"
#   ],
#   [
#     "disk_mops.vda",
#     "Disk Merged Operations (disk_mops.vda)"
#   ],
#   [
#     "disk_ext_mops.vda",
#     "Disk Merged Discard Operations (disk_ext_mops.vda)"
#   ],
#   [
#     "disk_iotime.vda",
#     "Disk Total I/O Time (disk_iotime.vda)"
#   ],
#   [
#     "disk_ext_iotime.vda",
#     "Disk Total I/O Time for Extended Operations (disk_ext_iotime.vda)"
#   ],
#   [
#     "disk.config-2",
#     "Disk I/O Bandwidth (disk.config-2)"
#   ],
#   [
#     "disk_ext.config-2",
#     "Amount of Discarded Data (disk_ext.config-2)"
#   ],
#   [
#     "disk_ops.config-2",
#     "Disk Completed I/O Operations (disk_ops.config-2)"
#   ],
#   [
#     "disk_ext_ops.config-2",
#     "Disk Completed Extended I/O Operations (disk_ext_ops.config-2)"
#   ],
#   [
#     "disk_qops.config-2",
#     "Disk Current I/O Operations (disk_qops.config-2)"
#   ],
#   [
#     "disk_backlog.config-2",
#     "Disk Backlog (disk_backlog.config-2)"
#   ],
#   [
#     "disk_busy.config-2",
#     "Disk Busy Time (disk_busy.config-2)"
#   ],
#   [
#     "disk_util.config-2",
#     "Disk Utilization Time (disk_util.config-2)"
#   ],
#   [
#     "disk_mops.config-2",
#     "Disk Merged Operations (disk_mops.config-2)"
#   ],
#   [
#     "disk_ext_mops.config-2",
#     "Disk Merged Discard Operations (disk_ext_mops.config-2)"
#   ],
#   [
#     "disk_iotime.config-2",
#     "Disk Total I/O Time (disk_iotime.config-2)"
#   ],
#   [
#     "disk_ext_iotime.config-2",
#     "Disk Total I/O Time for Extended Operations (disk_ext_iotime.config-2)"
#   ],
#   [
#     "system.io",
#     "Disk I/O (system.io)"
#   ],
#   [
#     "system.ipc_semaphore_arrays",
#     "IPC Semaphore Arrays (system.ipc_semaphore_arrays)"
#   ],
#   [
#     "system.ipc_semaphores",
#     "IPC Semaphores (system.ipc_semaphores)"
#   ],
#   [
#     "system.shared_memory_segments",
#     "IPC Shared Memory Number of Segments (system.shared_memory_segments)"
#   ],
#   [
#     "system.shared_memory_bytes",
#     "IPC Shared Memory Used Bytes (system.shared_memory_bytes)"
#   ],
#   [
#     "netdata.apps_cpu",
#     "Apps Plugin CPU (netdata.apps_cpu)"
#   ],
#   [
#     "netdata.apps_sizes",
#     "Apps Plugin Files (netdata.apps_sizes)"
#   ],
#   [
#     "system.processes_state",
#     "System Processes State (system.processes_state)"
#   ],
#   [
#     "app.nfacct_plugin_cpu_utilization",
#     "Applications Groups CPU utilization (100% = 1 core) (app.nfacct_plugin_cpu_utilization)"
#   ],
#   [
#     "app.nfacct_plugin_mem_private_usage",
#     "Applications Groups memory usage without shared (app.nfacct_plugin_mem_private_usage)"
#   ],
#   [
#     "app.nfacct_plugin_cpu_context_switches",
#     "Applications Groups CPU context switches (app.nfacct_plugin_cpu_context_switches)"
#   ],
#   [
#     "app.nfacct_plugin_mem_usage",
#     "Applications Groups memory RSS usage (app.nfacct_plugin_mem_usage)"
#   ],
#   [
#     "app.nfacct_plugin_vmem_usage",
#     "Applications Groups virtual memory size (app.nfacct_plugin_vmem_usage)"
#   ],
#   [
#     "app.nfacct_plugin_mem_page_faults",
#     "Applications Groups memory page faults (app.nfacct_plugin_mem_page_faults)"
#   ],
#   [
#     "app.nfacct_plugin_swap_usage",
#     "Applications Groups swap usage (app.nfacct_plugin_swap_usage)"
#   ],
#   [
#     "app.nfacct_plugin_disk_physical_io",
#     "Applications Groups disk physical IO (app.nfacct_plugin_disk_physical_io)"
#   ],
#   [
#     "app.nfacct_plugin_disk_logical_io",
#     "Applications Groups disk logical IO (app.nfacct_plugin_disk_logical_io)"
#   ],
#   [
#     "app.nfacct_plugin_processes",
#     "Applications Groups processes (app.nfacct_plugin_processes)"
#   ],
#   [
#     "app.nfacct_plugin_threads",
#     "Applications Groups threads (app.nfacct_plugin_threads)"
#   ],
#   [
#     "app.nfacct_plugin_fds_open_limit",
#     "Applications Groups open file descriptors limit (app.nfacct_plugin_fds_open_limit)"
#   ],
#   [
#     "app.nfacct_plugin_fds_open",
#     "Applications Groups open files descriptors (app.nfacct_plugin_fds_open)"
#   ],
#   [
#     "app.nfacct_plugin_uptime",
#     "Applications Groups uptime (app.nfacct_plugin_uptime)"
#   ],
#   [
#     "app.NETWORK-VIEWER_cpu_utilization",
#     "Applications Groups CPU utilization (100% = 1 core) (app.NETWORK-VIEWER_cpu_utilization)"
#   ],
#   [
#     "app.NETWORK-VIEWER_mem_private_usage",
#     "Applications Groups memory usage without shared (app.NETWORK-VIEWER_mem_private_usage)"
#   ],
#   [
#     "app.NETWORK-VIEWER_cpu_context_switches",
#     "Applications Groups CPU context switches (app.NETWORK-VIEWER_cpu_context_switches)"
#   ],
#   [
#     "app.NETWORK-VIEWER_mem_usage",
#     "Applications Groups memory RSS usage (app.NETWORK-VIEWER_mem_usage)"
#   ],
#   [
#     "app.NETWORK-VIEWER_vmem_usage",
#     "Applications Groups virtual memory size (app.NETWORK-VIEWER_vmem_usage)"
#   ],
#   [
#     "app.NETWORK-VIEWER_mem_page_faults",
#     "Applications Groups memory page faults (app.NETWORK-VIEWER_mem_page_faults)"
#   ],
#   [
#     "app.NETWORK-VIEWER_swap_usage",
#     "Applications Groups swap usage (app.NETWORK-VIEWER_swap_usage)"
#   ],
#   [
#     "app.NETWORK-VIEWER_disk_physical_io",
#     "Applications Groups disk physical IO (app.NETWORK-VIEWER_disk_physical_io)"
#   ],
#   [
#     "app.NETWORK-VIEWER_disk_logical_io",
#     "Applications Groups disk logical IO (app.NETWORK-VIEWER_disk_logical_io)"
#   ],
#   [
#     "app.NETWORK-VIEWER_processes",
#     "Applications Groups processes (app.NETWORK-VIEWER_processes)"
#   ],
#   [
#     "app.NETWORK-VIEWER_threads",
#     "Applications Groups threads (app.NETWORK-VIEWER_threads)"
#   ],
#   [
#     "app.NETWORK-VIEWER_fds_open_limit",
#     "Applications Groups open file descriptors limit (app.NETWORK-VIEWER_fds_open_limit)"
#   ],
#   [
#     "app.NETWORK-VIEWER_fds_open",
#     "Applications Groups open files descriptors (app.NETWORK-VIEWER_fds_open)"
#   ],
#   [
#     "app.NETWORK-VIEWER_uptime",
#     "Applications Groups uptime (app.NETWORK-VIEWER_uptime)"
#   ],
#   [
#     "app.ebpf_plugin_cpu_utilization",
#     "Applications Groups CPU utilization (100% = 1 core) (app.ebpf_plugin_cpu_utilization)"
#   ],
#   [
#     "app.ebpf_plugin_mem_private_usage",
#     "Applications Groups memory usage without shared (app.ebpf_plugin_mem_private_usage)"
#   ],
#   [
#     "app.ebpf_plugin_cpu_context_switches",
#     "Applications Groups CPU context switches (app.ebpf_plugin_cpu_context_switches)"
#   ],
#   [
#     "app.ebpf_plugin_mem_usage",
#     "Applications Groups memory RSS usage (app.ebpf_plugin_mem_usage)"
#   ],
#   [
#     "app.ebpf_plugin_vmem_usage",
#     "Applications Groups virtual memory size (app.ebpf_plugin_vmem_usage)"
#   ],
#   [
#     "app.ebpf_plugin_mem_page_faults",
#     "Applications Groups memory page faults (app.ebpf_plugin_mem_page_faults)"
#   ],
#   [
#     "app.ebpf_plugin_swap_usage",
#     "Applications Groups swap usage (app.ebpf_plugin_swap_usage)"
#   ],
#   [
#     "app.ebpf_plugin_disk_physical_io",
#     "Applications Groups disk physical IO (app.ebpf_plugin_disk_physical_io)"
#   ],
#   [
#     "app.ebpf_plugin_disk_logical_io",
#     "Applications Groups disk logical IO (app.ebpf_plugin_disk_logical_io)"
#   ],
#   [
#     "app.ebpf_plugin_processes",
#     "Applications Groups processes (app.ebpf_plugin_processes)"
#   ],
#   [
#     "app.ebpf_plugin_threads",
#     "Applications Groups threads (app.ebpf_plugin_threads)"
#   ],
#   [
#     "app.ebpf_plugin_fds_open_limit",
#     "Applications Groups open file descriptors limit (app.ebpf_plugin_fds_open_limit)"
#   ],
#   [
#     "app.ebpf_plugin_fds_open",
#     "Applications Groups open files descriptors (app.ebpf_plugin_fds_open)"
#   ],
#   [
#     "app.ebpf_plugin_uptime",
#     "Applications Groups uptime (app.ebpf_plugin_uptime)"
#   ],
#   [
#     "app.go_d_plugin_cpu_utilization",
#     "Applications Groups CPU utilization (100% = 1 core) (app.go_d_plugin_cpu_utilization)"
#   ],
#   [
#     "app.go_d_plugin_mem_private_usage",
#     "Applications Groups memory usage without shared (app.go_d_plugin_mem_private_usage)"
#   ],
#   [
#     "app.go_d_plugin_cpu_context_switches",
#     "Applications Groups CPU context switches (app.go_d_plugin_cpu_context_switches)"
#   ],
#   [
#     "app.go_d_plugin_mem_usage",
#     "Applications Groups memory RSS usage (app.go_d_plugin_mem_usage)"
#   ],
#   [
#     "app.go_d_plugin_vmem_usage",
#     "Applications Groups virtual memory size (app.go_d_plugin_vmem_usage)"
#   ],
#   [
#     "app.go_d_plugin_mem_page_faults",
#     "Applications Groups memory page faults (app.go_d_plugin_mem_page_faults)"
#   ],
#   [
#     "app.go_d_plugin_swap_usage",
#     "Applications Groups swap usage (app.go_d_plugin_swap_usage)"
#   ],
#   [
#     "app.go_d_plugin_disk_physical_io",
#     "Applications Groups disk physical IO (app.go_d_plugin_disk_physical_io)"
#   ],
#   [
#     "app.go_d_plugin_disk_logical_io",
#     "Applications Groups disk logical IO (app.go_d_plugin_disk_logical_io)"
#   ],
#   [
#     "app.go_d_plugin_processes",
#     "Applications Groups processes (app.go_d_plugin_processes)"
#   ],
#   [
#     "app.go_d_plugin_threads",
#     "Applications Groups threads (app.go_d_plugin_threads)"
#   ],
#   [
#     "app.go_d_plugin_fds_open_limit",
#     "Applications Groups open file descriptors limit (app.go_d_plugin_fds_open_limit)"
#   ],
#   [
#     "app.go_d_plugin_fds_open",
#     "Applications Groups open files descriptors (app.go_d_plugin_fds_open)"
#   ],
#   [
#     "app.go_d_plugin_uptime",
#     "Applications Groups uptime (app.go_d_plugin_uptime)"
#   ],
#   [
#     "app.debugfs_plugin_cpu_utilization",
#     "Applications Groups CPU utilization (100% = 1 core) (app.debugfs_plugin_cpu_utilization)"
#   ],
#   [
#     "app.debugfs_plugin_mem_private_usage",
#     "Applications Groups memory usage without shared (app.debugfs_plugin_mem_private_usage)"
#   ],
#   [
#     "app.debugfs_plugin_cpu_context_switches",
#     "Applications Groups CPU context switches (app.debugfs_plugin_cpu_context_switches)"
#   ],
#   [
#     "app.debugfs_plugin_mem_usage",
#     "Applications Groups memory RSS usage (app.debugfs_plugin_mem_usage)"
#   ],
#   [
#     "app.debugfs_plugin_vmem_usage",
#     "Applications Groups virtual memory size (app.debugfs_plugin_vmem_usage)"
#   ],
#   [
#     "app.debugfs_plugin_mem_page_faults",
#     "Applications Groups memory page faults (app.debugfs_plugin_mem_page_faults)"
#   ],
#   [
#     "app.debugfs_plugin_swap_usage",
#     "Applications Groups swap usage (app.debugfs_plugin_swap_usage)"
#   ],
#   [
#     "app.debugfs_plugin_disk_physical_io",
#     "Applications Groups disk physical IO (app.debugfs_plugin_disk_physical_io)"
#   ],
#   [
#     "app.debugfs_plugin_disk_logical_io",
#     "Applications Groups disk logical IO (app.debugfs_plugin_disk_logical_io)"
#   ],
#   [
#     "app.debugfs_plugin_processes",
#     "Applications Groups processes (app.debugfs_plugin_processes)"
#   ],
#   [
#     "app.debugfs_plugin_threads",
#     "Applications Groups threads (app.debugfs_plugin_threads)"
#   ],
#   [
#     "app.debugfs_plugin_fds_open_limit",
#     "Applications Groups open file descriptors limit (app.debugfs_plugin_fds_open_limit)"
#   ],
#   [
#     "app.debugfs_plugin_fds_open",
#     "Applications Groups open files descriptors (app.debugfs_plugin_fds_open)"
#   ],
#   [
#     "app.debugfs_plugin_uptime",
#     "Applications Groups uptime (app.debugfs_plugin_uptime)"
#   ],
#   [
#     "app.sd-jrnl_plugin_cpu_utilization",
#     "Applications Groups CPU utilization (100% = 1 core) (app.sd-jrnl_plugin_cpu_utilization)"
#   ],
#   [
#     "app.sd-jrnl_plugin_mem_private_usage",
#     "Applications Groups memory usage without shared (app.sd-jrnl_plugin_mem_private_usage)"
#   ],
#   [
#     "app.sd-jrnl_plugin_cpu_context_switches",
#     "Applications Groups CPU context switches (app.sd-jrnl_plugin_cpu_context_switches)"
#   ],
#   [
#     "app.sd-jrnl_plugin_mem_usage",
#     "Applications Groups memory RSS usage (app.sd-jrnl_plugin_mem_usage)"
#   ],
#   [
#     "app.sd-jrnl_plugin_vmem_usage",
# ...
#     "Systemd Services Number of Processes (systemd_systemd-logind.pids_current)"
#   ],
#   [
#     "netdata.go_d_httpcheck_Bangalore_Demo_Site_(CloudFlare)_data_collection_status",
#     "Data Collection Status (netdata.go_d_httpcheck_Bangalore_Demo_Site_(CloudFlare)_data_collection_status)"
#   ],
#   [
#     "netdata.go_d_httpcheck_Bangalore_Demo_Site_(CloudFlare)_data_collection_duration",
#     "Data Collection Duration (netdata.go_d_httpcheck_Bangalore_Demo_Site_(CloudFlare)_data_collection_duration)"
#   ],
#   [
#     "httpcheck_Bangalore_Demo_Site_(CloudFlare).response_time",
#     "HTTP Response Time (httpcheck_Bangalore_Demo_Site_(CloudFlare).response_time)"
#   ],
#   [
#     "httpcheck_Bangalore_Demo_Site_(CloudFlare).response_length",
#     "HTTP Response Body Length (httpcheck_Bangalore_Demo_Site_(CloudFlare).response_length)"
#   ],
#   [
#     "httpcheck_Bangalore_Demo_Site_(CloudFlare).request_status",
#     "HTTP Check Status (httpcheck_Bangalore_Demo_Site_(CloudFlare).request_status)"
#   ],
#   [
#     "httpcheck_Bangalore_Demo_Site_(CloudFlare).current_state_duration",
#     "HTTP Current State Duration (httpcheck_Bangalore_Demo_Site_(CloudFlare).current_state_duration)"
#   ],
#   [
#     "user.sshd_cpu_utilization",
#     "User Processes CPU utilization (100% = 1 core) (user.sshd_cpu_utilization)"
#   ],
#   [
#     "user.sshd_mem_private_usage",
#     "User Processes memory usage without shared (user.sshd_mem_private_usage)"
#   ],
#   [
#     "user.sshd_cpu_context_switches",
#     "User Processes CPU context switches (user.sshd_cpu_context_switches)"
#   ],
#   [
#     "user.sshd_mem_usage",
#     "User Processes memory RSS usage (user.sshd_mem_usage)"
#   ],
#   [
#     "user.sshd_vmem_usage",
#     "User Processes virtual memory size (user.sshd_vmem_usage)"
#   ],
#   [
#     "user.sshd_mem_page_faults",
#     "User Processes memory page faults (user.sshd_mem_page_faults)"
#   ],
#   [
#     "user.sshd_swap_usage",
#     "User Processes swap usage (user.sshd_swap_usage)"
#   ],
#   [
#     "user.sshd_disk_physical_io",
#     "User Processes disk physical IO (user.sshd_disk_physical_io)"
#   ],
#   [
#     "user.sshd_disk_logical_io",
#     "User Processes disk logical IO (user.sshd_disk_logical_io)"
#   ],
#   [
#     "user.sshd_processes",
#     "User Processes processes (user.sshd_processes)"
#   ],
#   [
#     "user.sshd_threads",
#     "User Processes threads (user.sshd_threads)"
#   ],
#   [
#     "user.sshd_fds_open_limit",
#     "User Processes open file descriptors limit (user.sshd_fds_open_limit)"
#   ],
#   [
#     "user.sshd_fds_open",
#     "User Processes open files descriptors (user.sshd_fds_open)"
#   ],
#   [
#     "user.sshd_uptime",
#     "User Processes uptime (user.sshd_uptime)"
#   ],
#   [
#     "usergroup.nogroup_cpu_utilization",
#     "User Group Processes CPU utilization (100% = 1 core) (usergroup.nogroup_cpu_utilization)"
#   ],
#   [
#     "usergroup.nogroup_mem_private_usage",
#     "User Group Processes memory usage without shared (usergroup.nogroup_mem_private_usage)"
#   ],
#   [
#     "usergroup.nogroup_cpu_context_switches",
#     "User Group Processes CPU context switches (usergroup.nogroup_cpu_context_switches)"
#   ],
#   [
#     "usergroup.nogroup_mem_usage",
#     "User Group Processes memory RSS usage (usergroup.nogroup_mem_usage)"
#   ],
#   [
#     "usergroup.nogroup_vmem_usage",
#     "User Group Processes virtual memory size (usergroup.nogroup_vmem_usage)"
#   ],
#   [
#     "usergroup.nogroup_mem_page_faults",
#     "User Group Processes memory page faults (usergroup.nogroup_mem_page_faults)"
#   ],
#   [
#     "usergroup.nogroup_swap_usage",
#     "User Group Processes swap usage (usergroup.nogroup_swap_usage)"
#   ],
#   [
#     "usergroup.nogroup_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.nogroup_disk_physical_io)"
#   ],
#   [
#     "usergroup.nogroup_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.nogroup_disk_logical_io)"
#   ],
#   [
#     "usergroup.nogroup_processes",
#     "User Group Processes processes (usergroup.nogroup_processes)"
#   ],
#   [
#     "usergroup.nogroup_threads",
#     "User Group Processes threads (usergroup.nogroup_threads)"
#   ],
#   [
#     "usergroup.nogroup_fds_open_limit",
#     "User Group Processes open file descriptors limit (usergroup.nogroup_fds_open_limit)"
#   ],
#   [
#     "usergroup.nogroup_fds_open",
#     "User Group Processes open files descriptors (usergroup.nogroup_fds_open)"
#   ],
#   [
#     "usergroup.nogroup_uptime",
#     "User Group Processes uptime (usergroup.nogroup_uptime)"
#   ],
#   [
#     "netdata.workers_threads_stream",
#     "Netdata Workers Threads (netdata.workers_threads_stream)"
#   ],
#   [
#     "usergroup.postdrop_cpu_utilization",
#     "User Group Processes CPU utilization (100% = 1 core) (usergroup.postdrop_cpu_utilization)"
#   ],
#   [
#     "usergroup.postdrop_mem_private_usage",
#     "User Group Processes memory usage without shared (usergroup.postdrop_mem_private_usage)"
#   ],
#   [
#     "usergroup.postdrop_cpu_context_switches",
#     "User Group Processes CPU context switches (usergroup.postdrop_cpu_context_switches)"
#   ],
#   [
#     "usergroup.postdrop_mem_usage",
#     "User Group Processes memory RSS usage (usergroup.postdrop_mem_usage)"
#   ],
#   [
#     "usergroup.postdrop_vmem_usage",
#     "User Group Processes virtual memory size (usergroup.postdrop_vmem_usage)"
#   ],
#   [
#     "usergroup.postdrop_mem_page_faults",
#     "User Group Processes memory page faults (usergroup.postdrop_mem_page_faults)"
#   ],
#   [
#     "usergroup.postdrop_swap_usage",
#     "User Group Processes swap usage (usergroup.postdrop_swap_usage)"
#   ],
#   [
#     "usergroup.postdrop_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.postdrop_disk_physical_io)"
#   ],
#   [
#     "usergroup.postdrop_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.postdrop_disk_logical_io)"
#   ],
#   [
#     "usergroup.postdrop_processes",
#     "User Group Processes processes (usergroup.postdrop_processes)"
#   ],
#   [
#     "usergroup.postdrop_threads",
#     "User Group Processes threads (usergroup.postdrop_threads)"
#   ],
#   [
#     "usergroup.postdrop_fds_open_limit",
#     "User Group Processes open file descriptors limit (usergroup.postdrop_fds_open_limit)"
#   ],
#   [
#     "usergroup.postdrop_fds_open",
#     "User Group Processes open files descriptors (usergroup.postdrop_fds_open)"
#   ],
#   [
#     "usergroup.postdrop_uptime",
#     "User Group Processes uptime (usergroup.postdrop_uptime)"
#   ],
#   [
#     "user._apt_cpu_utilization",
#     "User Processes CPU utilization (100% = 1 core) (user._apt_cpu_utilization)"
#   ],
#   [
#     "user._apt_mem_private_usage",
#     "User Processes memory usage without shared (user._apt_mem_private_usage)"
#   ],
#   [
#     "user._apt_cpu_context_switches",
#     "User Processes CPU context switches (user._apt_cpu_context_switches)"
#   ],
#   [
#     "user._apt_mem_usage",
#     "User Processes memory RSS usage (user._apt_mem_usage)"
#   ],
#   [
#     "user._apt_vmem_usage",
#     "User Processes virtual memory size (user._apt_vmem_usage)"
#   ],
#   [
#     "user._apt_mem_page_faults",
#     "User Processes memory page faults (user._apt_mem_page_faults)"
#   ],
#   [
#     "user._apt_swap_usage",
#     "User Processes swap usage (user._apt_swap_usage)"
#   ],
#   [
#     "user._apt_disk_physical_io",
#     "User Processes disk physical IO (user._apt_disk_physical_io)"
#   ],
#   [
#     "user._apt_disk_logical_io",
#     "User Processes disk logical IO (user._apt_disk_logical_io)"
#   ],
#   [
#     "user._apt_processes",
#     "User Processes processes (user._apt_processes)"
#   ],
#   [
#     "user._apt_threads",
#     "User Processes threads (user._apt_threads)"
#   ],
#   [
#     "user._apt_fds_open_limit",
#     "User Processes open file descriptors limit (user._apt_fds_open_limit)"
#   ],
#   [
#     "user._apt_fds_open",
#     "User Processes open files descriptors (user._apt_fds_open)"
#   ],
#   [
#     "user._apt_uptime",
#     "User Processes uptime (user._apt_uptime)"
#   ],
#   [
#     "app.backup_cpu_utilization",
#     "Applications Groups CPU utilization (100% = 1 core) (app.backup_cpu_utilization)"
#   ],
#   [
#     "app.backup_mem_private_usage",
#     "Applications Groups memory usage without shared (app.backup_mem_private_usage)"
#   ],
#   [
#     "app.backup_cpu_context_switches",
#     "Applications Groups CPU context switches (app.backup_cpu_context_switches)"
#   ],
#   [
#     "app.backup_mem_usage",
#     "Applications Groups memory RSS usage (app.backup_mem_usage)"
#   ],
#   [
#     "app.backup_vmem_usage",
#     "Applications Groups virtual memory size (app.backup_vmem_usage)"
#   ],
#   [
#     "app.backup_mem_page_faults",
#     "Applications Groups memory page faults (app.backup_mem_page_faults)"
#   ],
#   [
#     "app.backup_swap_usage",
#     "Applications Groups swap usage (app.backup_swap_usage)"
#   ],
#   [
#     "app.backup_disk_physical_io",
#     "Applications Groups disk physical IO (app.backup_disk_physical_io)"
#   ],
#   [
#     "app.backup_disk_logical_io",
#     "Applications Groups disk logical IO (app.backup_disk_logical_io)"
#   ],
#   [
#     "app.backup_processes",
#     "Applications Groups processes (app.backup_processes)"
#   ],
#   [
#     "app.backup_threads",
#     "Applications Groups threads (app.backup_threads)"
#   ],
#   [
#     "app.backup_fds_open_limit",
#     "Applications Groups open file descriptors limit (app.backup_fds_open_limit)"
#   ],
#   [
#     "app.backup_fds_open",
#     "Applications Groups open files descriptors (app.backup_fds_open)"
#   ],
#   [
#     "app.backup_uptime",
#     "Applications Groups uptime (app.backup_uptime)"
#   ],
#   [
#     "app.alarm-notify_cpu_utilization",
#     "Applications Groups CPU utilization (100% = 1 core) (app.alarm-notify_cpu_utilization)"
#   ],
#   [
#     "app.alarm-notify_mem_private_usage",
#     "Applications Groups memory usage without shared (app.alarm-notify_mem_private_usage)"
#   ],
#   [
#     "app.alarm-notify_cpu_context_switches",
#     "Applications Groups CPU context switches (app.alarm-notify_cpu_context_switches)"
#   ],
#   [
#     "app.alarm-notify_mem_usage",
#     "Applications Groups memory RSS usage (app.alarm-notify_mem_usage)"
#   ],
#   [
#     "app.alarm-notify_vmem_usage",
#     "Applications Groups virtual memory size (app.alarm-notify_vmem_usage)"
#   ],
#   [
#     "app.alarm-notify_mem_page_faults",
#     "Applications Groups memory page faults (app.alarm-notify_mem_page_faults)"
#   ],
#   [
#     "app.alarm-notify_swap_usage",
#     "Applications Groups swap usage (app.alarm-notify_swap_usage)"
#   ],
#   [
#     "app.alarm-notify_disk_physical_io",
#     "Applications Groups disk physical IO (app.alarm-notify_disk_physical_io)"
#   ],
#   [
#     "app.alarm-notify_disk_logical_io",
#     "Applications Groups disk logical IO (app.alarm-notify_disk_logical_io)"
#   ],
#   [
#     "app.alarm-notify_processes",
#     "Applications Groups processes (app.alarm-notify_processes)"
#   ],
#   [
#     "app.alarm-notify_threads",
#     "Applications Groups threads (app.alarm-notify_threads)"
#   ],
#   [
#     "app.alarm-notify_fds_open_limit",
#     "Applications Groups open file descriptors limit (app.alarm-notify_fds_open_limit)"
#   ],
#   [
#     "app.alarm-notify_fds_open",
#     "Applications Groups open files descriptors (app.alarm-notify_fds_open)"
#   ],
#   [
#     "app.alarm-notify_uptime",
#     "Applications Groups uptime (app.alarm-notify_uptime)"
#   ],
#   [
#     "app.apt_systemd_daily_cpu_utilization",
#     "Applications Groups CPU utilization (100% = 1 core) (app.apt_systemd_daily_cpu_utilization)"
#   ],
#   [
#     "app.apt_systemd_daily_mem_private_usage",
#     "Applications Groups memory usage without shared (app.apt_systemd_daily_mem_private_usage)"
#   ],
#   [
#     "app.apt_systemd_daily_cpu_context_switches",
#     "Applications Groups CPU context switches (app.apt_systemd_daily_cpu_context_switches)"
#   ],
#   [
#     "app.apt_systemd_daily_mem_usage",
#     "Applications Groups memory RSS usage (app.apt_systemd_daily_mem_usage)"
#   ],
#   [
#     "app.apt_systemd_daily_vmem_usage",
#     "Applications Groups virtual memory size (app.apt_systemd_daily_vmem_usage)"
#   ],
#   [
#     "app.apt_systemd_daily_mem_page_faults",
#     "Applications Groups memory page faults (app.apt_systemd_daily_mem_page_faults)"
#   ],
#   [
#     "app.apt_systemd_daily_swap_usage",
#     "Applications Groups swap usage (app.apt_systemd_daily_swap_usage)"
#   ],
#   [
#     "app.apt_systemd_daily_disk_physical_io",
#     "Applications Groups disk physical IO (app.apt_systemd_daily_disk_physical_io)"
#   ],
#   [
#     "app.apt_systemd_daily_disk_logical_io",
#     "Applications Groups disk logical IO (app.apt_systemd_daily_disk_logical_io)"
#   ],
#   [
#     "app.apt_systemd_daily_processes",
#     "Applications Groups processes (app.apt_systemd_daily_processes)"
#   ],
#   [
#     "app.apt_systemd_daily_threads",
#     "Applications Groups threads (app.apt_systemd_daily_threads)"
#   ],
#   [
#     "app.apt_systemd_daily_fds_open_limit",
#     "Applications Groups open file descriptors limit (app.apt_systemd_daily_fds_open_limit)"
#   ],
#   [
#     "app.apt_systemd_daily_fds_open",
#     "Applications Groups open files descriptors (app.apt_systemd_daily_fds_open)"
#   ],
#   [
#     "app.apt_systemd_daily_uptime",
#     "Applications Groups uptime (app.apt_systemd_daily_uptime)"
#   ],
#   [
#     "app.certbot_cpu_utilization",
#     "Applications Groups CPU utilization (100% = 1 core) (app.certbot_cpu_utilization)"
#   ],
#   [
#     "app.certbot_mem_private_usage",
#     "Applications Groups memory usage without shared (app.certbot_mem_private_usage)"
#   ],
#   [
#     "app.certbot_cpu_context_switches",
#     "Applications Groups CPU context switches (app.certbot_cpu_context_switches)"
#   ],
#   [
#     "app.certbot_mem_usage",
#     "Applications Groups memory RSS usage (app.certbot_mem_usage)"
#   ],
#   [
#     "app.certbot_vmem_usage",
#     "Applications Groups virtual memory size (app.certbot_vmem_usage)"
#   ],
#   [
#     "app.certbot_mem_page_faults",
#     "Applications Groups memory page faults (app.certbot_mem_page_faults)"
#   ],
#   [
#     "app.certbot_swap_usage",
#     "Applications Groups swap usage (app.certbot_swap_usage)"
#   ],
#   [
#     "app.certbot_disk_physical_io",
#     "Applications Groups disk physical IO (app.certbot_disk_physical_io)"
#   ],
#   [
#     "app.certbot_disk_logical_io",
#     "Applications Groups disk logical IO (app.certbot_disk_logical_io)"
#   ],
#   [
#     "app.certbot_processes",
#     "Applications Groups processes (app.certbot_processes)"
#   ],
#   [
#     "app.certbot_threads",
#     "Applications Groups threads (app.certbot_threads)"
#   ],
#   [
#     "app.certbot_fds_open_limit",
#     "Applications Groups open file descriptors limit (app.certbot_fds_open_limit)"
#   ],
#   [
#     "app.certbot_fds_open",
#     "Applications Groups open files descriptors (app.certbot_fds_open)"
#   ],
#   [
#     "app.certbot_uptime",
#     "Applications Groups uptime (app.certbot_uptime)"
#   ]
# ]
# ================================== Ai Message ==================================
# Tool Calls:
#   get_chart_data (call_ExvOtkjnmJMnGQVjP2wOaeE7)
#  Call ID: call_ExvOtkjnmJMnGQVjP2wOaeE7
#   Args:
#     netdata_host_url: https://london3.my-netdata.io/
#     chart: disk_space./
# ================================= Tool Message =================================
# Name: get_chart_data
#
#     avail     used  reserved for root
# 112.80312 38.20478           6.435379
# 112.80304 38.20486           6.435379
# 112.80283 38.20507           6.435379
# 112.80276 38.20515           6.435379
# 112.80270 38.20520           6.435379
# 112.80269 38.20521           6.435379
# 112.80264 38.20527           6.435379
# 112.80259 38.20532           6.435379
# 112.80248 38.20542           6.435379
# 112.80241 38.20549           6.435379
# 112.80232 38.20558           6.435379
# 112.80225 38.20566           6.435379
# ================================== Ai Message ==================================
#
# On the London server, the current disk space usage is as follows:
#
# - **Available Disk Space:** Approximately 112.80 GB
# - **Used Disk Space:** Approximately 38.20 GB
# - **Reserved for root:** Approximately 6.44 GB
#
# Would you like to know anything else?
# ================================== Ai Message ==================================
#
# On the London server, the current disk space usage is as follows:
#
# - **Available Disk Space:** Approximately 112.80 GB
# - **Used Disk Space:** Approximately 38.20 GB
# - **Reserved for root:** Approximately 6.44 GB
#
# Would you like to know anything else?

# %%
# chat with agent
msg = 'What hosts are reachable from the london node?'
print_md(agent.chat(msg, return_last=True))
# Out:
# The following hosts are reachable from the London node:
#
# 1. **registry.my-netdata.io** - 0 hops
# 2. **toronto.netdata.rocks** - 6 hops
# 3. **sanfrancisco** - 6 hops
# 4. **frankfurt.netdata.rocks** - 4 hops
# 5. **newyork.netdata.rocks** - 4 hops
# 6. **singapore.netdata.rocks** - 6 hops
# 7. **d1.firehol.org** - 4 hops
# 8. **bangalore** - 3 hops
#
# The host **cdn77** is not reachable.

# %%
msg = 'What is my CPU utilization recently on london?'
print_md(agent.chat(msg, return_last=True))
# Out:
# Over the past hour, the CPU utilization on the London server (`https://london3.my-netdata.io/`) has varied across different components. Here's a summary of CPU usage in percentages for key components:
#
# - **User** CPU utilization has fluctuated, with an average around 4.3%.
# - **System** CPU utilization has averaged around 1.8%.
# - **I/O Wait** has been minimal, averaging around 0.02%.
# - **SoftIRQ** has hovered around 0.64%.
# - **Steal** has been very low, averaging around 0.09%.
#
# These values indicate a relatively low load on the system, with user processes consuming the majority of CPU resources. If you need more detailed analysis or further breakdowns, feel free to ask!

# %%
msg = 'What apps are using most cpu on new york over the last 15 minutes?'
print_md(agent.chat(msg, return_last=True))
# Out:
# Over the last 15 minutes, here are the CPU utilization metrics for several applications on the New York node:
#
# 1. **app.go_d_plugin_cpu_utilization**:
#    - Average User CPU: 0.58
#    - Average System CPU: 0.28
#
# 2. **app.ebpf_plugin_cpu_utilization**:
#    - Average User CPU: 0.00
#    - Average System CPU: 0.05
#
# 3. **app.NETWORK-VIEWER_cpu_utilization**:
#    - Average User CPU: 0.00
#    - Average System CPU: 0.00
#
# 4. **app.nfacct_plugin_cpu_utilization**:
#    - Average User CPU: 0.00
#    - Average System CPU: 0.00
#
# 5. **app.systemd_cpu_utilization**:
#    - Average User CPU: 0.51
#    - Average System CPU: 0.02
#
# 6. **app.netdata_cpu_utilization**:
#    - Average User CPU: 0.49
#    - Average System CPU: 0.42
#
# 7. **app.httpd_cpu_utilization**:
#    - Average User CPU: 9.00 (notable peak)
#    - Average System CPU: 2.07
#
# 8. **app.vpn_cpu_utilization**:
#    - Average User CPU: 0.00
#    - Average System CPU: 0.09
#
# 9. **app.logs_cpu_utilization**:
#    - Average User CPU: 0.00
#    - Average System CPU: 0.09
#
# 10. **app.nfs_cpu_utilization**:
#     - Average User CPU: 0.00
#     - Average System CPU: 0.00
#
# ### Notable Observations:
# - The **app.httpd_cpu_utilization** has the highest CPU utilization, particularly in User CPU usage.
# - Several applications show negligible or zero CPU utilization over this period.
#
# Please let me know if you need more specific information or other charts!

# %%
msg = 'What users are using most cpu on sanfransicso the last hour?'
print_md(agent.chat(msg, return_last=True))
# Out:
# Here are the user processes' CPU utilization percentages over the last hour in San Francisco. The values represent the average utilization for each data point taken at intervals within the hour:
#
# - User CPU Utilization: Averages between roughly 8.5% to 10.5%.
# - System CPU Utilization: Ranges between approximately 2.1% to 3.0%.
#
# Note that there are some missing data points. However, overall trends indicate that user processes are consuming significantly more CPU than system processes. If you need a specific breakdown by users, further analysis can be performed based on user-specific data if available.

# %%
msg = 'What specific users are using most cpu on bangalore?'
print_md(agent.chat(msg, return_last=True))
# Out:
# On the Bangalore node, the current CPU utilization by specific users is as follows:
#
# 1. **User `netdata`**
#    - User CPU Utilization: 12.000247%
#    - System CPU Utilization: 4.6673811%
#
# 2. **User `root`**
#    - User CPU Utilization: 2.0012143%
#    - System CPU Utilization: 3.3342598%
#    - Total CPU Utilization: 5.3354741%
#
# 3. **User `www-data`**
#    - User CPU Utilization: 0%
#    - System CPU Utilization: 0%
#    - Total CPU Utilization: 0%
#
# 4. **User `Debian-exim`**
#    - User CPU Utilization: 0%
#    - System CPU Utilization: 0%
#    - Total CPU Utilization: 0%
#
# 5. **User `unbound`**
#    - User CPU Utilization: 0%
#    - System CPU Utilization: 0%
#    - Total CPU Utilization: 0%
#
# 6. **User `daemon`**
#    - User CPU Utilization: 0%
#    - System CPU Utilization: 0%
#    - Total CPU Utilization: 0%
#
# 7. **User `logind`** (in the context of users, like sessions)
#    - Online Users: 0
#    - Active Users: 0
#
# Based on the current data, the user `netdata` is utilizing the highest CPU among the users, followed by `root`. Other users are not consuming any CPU resources at this time.

# %%
msg = 'what is the ram usage like on bangalore node?'
print_md(agent.chat(msg, return_last=True))
# Out:
# The RAM usage on the Bangalore node is as follows (in MB):
#
# - **Free RAM**: varies between approximately 157 MB to 170 MB.
# - **Used RAM**: hovers around 951 MB to 964 MB.
# - **Cached**: remains steady at approximately 717 MB.
# - **Buffers**: remains steady at approximately 127 MB.
#
# These values give a snapshot of the current RAM utilization.

# %%
msg = 'How are the mysql metrics looking on the london?'
print_md(agent.chat(msg, return_last=True))
# Out:
# Here's a quick summary of the current MySQL metrics for the London host:
#
# 1. **CPU Utilization**:
#    - User CPU utilization fluctuates between approximately 0.28 to 0.48.
#    - System CPU utilization remains much lower in comparison, occasionally spiking.
#
# 2. **Memory Usage**:
#    - Unfortunately, there was an SSL error while attempting to retrieve memory usage data, preventing a complete analysis. It may be necessary to check the connection or the server's SSL configuration.
#
# 3. **Connections**:
#    - The data indicates no open or aborted connections for the checked interval.
#
# 4. **Queries**:
#    - Both regular and slow queries appear steady, maintaining a rate of approximately six queries/sec, with no slow queries detected in the last few minutes.
#
# If you have any specific metrics you'd like me to investigate or need further assistance, feel free to ask!

# %%
msg = 'any active alarms on toronto?'
print_md(agent.chat(msg, return_last=True))
# Out:
# There are currently two active alarms on the Toronto Netdata instance:
#
# 1. **Alarm Name:** 10min_qos_packet_drops
#    - **Chart:** `tc.eth0_dropped`
#    - **Status:** WARNING
#    - **Value:** 2 packets
#    - **Info:** Dropped packets in the last 5 minutes
#    - **Summary:** QOS packet drops
#
# 2. **Alarm Name:** 10min_qos_packet_drops
#    - **Chart:** `tc.eth0-ifb_dropped`
#    - **Status:** WARNING
#    - **Value:** 4 packets
#    - **Info:** Dropped packets in the last 5 minutes
#    - **Summary:** QOS packet drops
#
# Both alarms indicate that there are packet drops occurring in the specified time frame.

# %%
msg = 'what do the alarms mean? should i be worried?'
print_md(agent.chat(msg, return_last=True, continue_chat=True))
# Out:
# The active alarms indicate that there are packets being dropped in the network interface cards monitored by the respective charts. Here's a breakdown of what this means:
#
# 1. **Packet Drops**: Packet drops occur when a device cannot process incoming packets fast enough. This can be due to several reasons such as high traffic, insufficient resources (CPU, memory), network congestion, or hardware issues.
#
# 2. **Implications**:
#    - If your application relies on real-time communication (like VoIP, online gaming, or streaming services), packet drops can lead to performance issues like lag, interruptions, or lower quality service.
#    - If this is happening on a critical service or application, it may affect the availability or reliability of your services.
#
# 3. **Should You Be Worried?**:
#    - **Short Intervals**: If this is a transient issue (i.e., it happens for a short time and is followed by no further drops), it may not be a major concern.
#    - **Persisting Issues**: If these alarms persist, you should investigate the cause. It may require tuning your network settings, allocating more resources, or checking for hardware issues.
#
# ### Recommended Actions:
# - Monitor the charts for trends in packet drops.
# - Check the health of your network equipment (routers, switches).
# - Analyze traffic patterns to see if there are spikes in usage that coincide with the packet drops.
# - Consider setting up additional alarms or performance metrics to get alerted if the situation worsens.
#
# In summary, while packet drops are a cause for concern, especially if they’re consistent, they are not necessarily an immediate crisis. Proactive monitoring and analysis will help ensure that any potential issues are managed swiftly.

# %%
msg = 'How are the nginx metrics looking on the london node over he last couple of hours?'
print_md(agent.chat(msg, return_last=True))
# Out:
# Here's a summary of the Nginx metrics on the London node over the last couple of hours:
#
# 1. **Connections**: The average number of active connections is around 151, with fluctuations between 135 and 167 observed periodically.
#
# 2. **Requests**: Approximately 10–11 requests were handled on average per data point during the period.
#
# 3. **Accepted and Handled Connections**: There's a steady rate of accepted and handled connections, which appears to hover slightly under 1 connection per data interval on average.
#
# 4. **Connection Status**:
#    - Most connections are idle, ranging from around 128 to 166 on average.
#    - The number of active writing connections is generally stable at about 1.
#
# These metrics indicate relatively steady activity on the Nginx server in London with no significant variations observed in the last couple of hours. If you need further details or have specific questions about these metrics, feel free to ask!
