# %%
from netdata_llm_agent import NetdataLLMAgent

# create agent
agent = NetdataLLMAgent(base_url='https://london3.my-netdata.io/')

# chat with agent
agent.chat('What hosts are reachable from this node?', verbose=True)
# Out:
# ================================ Human Message =================================
#
# What hosts are reachable from this node?
# ================================== Ai Message ==================================
# Tool Calls:
#   get_netdata_info (call_EKqjsddoS8Y6E0lsrU5riOOL)
#  Call ID: call_EKqjsddoS8Y6E0lsrU5riOOL
#   Args:
#     base_url: https://london3.my-netdata.io/
# ================================= Tool Message =================================
# Name: get_netdata_info
#
# {
#   "netdata_version": "v2.2.0-70-nightly",
#   "hostname": "registry.my-netdata.io",
#   "operating_system": "Debian GNU/Linux",
#   "operating_system_version": "debian",
#   "cores_total": "4",
#   "total_disk_space": "171799128064",
#   "ram_total": "8326430720",
#   "mirrored_hosts_status": [
#     {
#       "hostname": "registry.my-netdata.io",
#       "hops": 0,
#       "reachable": true,
#       "guid": "792bb46a-fb11-11e7-b935-e6a17492adc8",
# ...

# %%
agent.chat('What is my CPU utilization recently', verbose=False)
# Out:
# ================================== Ai Message ==================================
#
# Here is your recent CPU utilization breakdown:
#
# - **User CPU:**
#   - Highest: 14.96%
#   - Lowest: 2.79%
#   - Recent Usage: Ranges around 3-6%
#
# - **System CPU:**
#   - Mostly around 1.5% to 2.8%
#
# - **I/O Wait:**
#   - Majority: Very low or 0%
#
# - **Soft IRQ:**
#   - Peaks up to 1.25% occasionally
#
# - **Steal CPU:**
#   - Mostly low, occasionally peaking around 2%
#
# Overall, your recent CPU utilization shows more activity in the user and system spaces, with moderated softirq and steal times. It seems your system is not heavily loaded at the moment.

# %%
agent.chat('What apps are using most cpu? over the last 15 minutes lets say', verbose=False)
# Out:
# ================================== Ai Message ==================================
#
# Over the past 15 minutes, the apps with the highest CPU utilization have shown varied usage, with user space CPU usage peaking around 6% and system space CPU usage ranging up to approximately 9%. The applications consuming the most CPU resources seem to fluctuate between user space and system operations with no specific app consistently dominating the CPU usage. To get a more granular view, a detailed analysis of each process within these categories would be necessary.

# %%
agent.chat('What users are using most cpu over the last hour?', verbose=True)
# Out:
# ================================ Human Message =================================
#
# What users are using most cpu over the last hour?
# ================================== Ai Message ==================================
# Tool Calls:
#   get_netdata_chart_data (call_bJwivBaphUdJYlBSWoG1noBO)
#  Call ID: call_bJwivBaphUdJYlBSWoG1noBO
#   Args:
#     base_url: https://london3.my-netdata.io/
#     chart: users.cpu
#     after: -3600
# ================================= Tool Message =================================
# Name: get_netdata_chart_data
#
# Error: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')
#  Please fix your mistakes.
# ================================== Ai Message ==================================
#
# It seems there was an error retrieving the data. Let me try accessing the chart data again to investigate the issue.
# Tool Calls:
#   get_netdata_charts (call_Zv79FzJEUWkmI46Zo5Tk65ig)
#  Call ID: call_Zv79FzJEUWkmI46Zo5Tk65ig
#   Args:
# ...

# %%
agent.chat('What specific users are using most cpu?', verbose=True, continue_chat=True)
# Out:
# ================================ Human Message =================================
#
# What users are using most cpu over the last hour?
# ================================== Ai Message ==================================
# Tool Calls:
#   get_netdata_chart_data (call_bJwivBaphUdJYlBSWoG1noBO)
#  Call ID: call_bJwivBaphUdJYlBSWoG1noBO
#   Args:
#     base_url: https://london3.my-netdata.io/
#     chart: users.cpu
#     after: -3600
# ================================= Tool Message =================================
# Name: get_netdata_chart_data
#
# Error: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')
#  Please fix your mistakes.
# ================================== Ai Message ==================================
#
# It seems there was an error retrieving the data. Let me try accessing the chart data again to investigate the issue.
# Tool Calls:
#   get_netdata_charts (call_Zv79FzJEUWkmI46Zo5Tk65ig)
#  Call ID: call_Zv79FzJEUWkmI46Zo5Tk65ig
#   Args:
# ...
