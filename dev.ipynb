# %%
import json 
import random
from netdata_llm_tools import get_alarms, get_charts, get_anomaly_rates, get_netdata_docs_sitemap, get_netdata_docs_page

netdata_url = 'http://localhost:19999'

# %%
urls = json.loads(get_netdata_docs_sitemap())
# random url
url = urls[random.randint(0,len(urls)-1)]
print(url)
x = get_netdata_docs_page(url)
print(x)
# Out:
# https://learn.netdata.cloud/docs/collecting-metrics/databases/cockroachdb
#
#
#
# CockroachDB | Learn Netdata
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [Skip to main content](#__docusaurus_skipToContent_fallback)[![Netdata Logo](/img/logo-letter-green-white.svg)![Netdata Logo](/img/logo-letter-green-white.svg)](/)[Features](https://www.netdata.cloud/features/)[Open Source](https://www.netdata.cloud/open-source/)[Pricing](https://www.netdata.cloud/pricing/)[Integrations](https://www.netdata.cloud/integrations/)[Use cases](#)
#
# * [Response Time](https://www.netdata.cloud/response-time-monitoring/)
# * [Cloud](https://www.netdata.cloud/cloud-monitoring/)
# * [Web Servers](https://www.netdata.cloud/webserver-monitoring/)
# * [Containers](https://www.netdata.cloud/container-monitoring/)
# [Resources](#)
#
# * [Documentation](/docs/deployment-guides/)
# * [Community](https://www.netdata.cloud/community/)
# * [About](https://www.netdata.cloud/about/)
# * [Forums](https://community.netdata.cloud/)
# ...

# %%
len(x)
# Out:
# 21822
