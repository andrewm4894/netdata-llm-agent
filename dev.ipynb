# %%
from netdata_tools import get_alarms, get_charts

netdata_url = 'http://localhost:19999'

# %%
x = get_charts(netdata_url,search_term='app.')
print(x)
# Out:
# [
#   [
#     "app.anonymous-statistics_cpu_utilization",
#     "Applications Groups CPU utilization (100% = 1 core) (app.anonymous-statistics_cpu_utilization)"
#   ],
#   [
#     "app.anonymous-statistics_mem_private_usage",
#     "Applications Groups memory usage without shared (app.anonymous-statistics_mem_private_usage)"
#   ],
#   [
#     "app.anonymous-statistics_mem_usage",
#     "Applications Groups memory RSS usage (app.anonymous-statistics_mem_usage)"
#   ],
#   [
#     "app.anonymous-statistics_vmem_usage",
#     "Applications Groups virtual memory size (app.anonymous-statistics_vmem_usage)"
#   ],
#   [
#     "app.anonymous-statistics_mem_page_faults",
#     "Applications Groups memory page faults (app.anonymous-statistics_mem_page_faults)"
#   ],
#   [
#     "app.anonymous-statistics_swap_usage",
#     "Applications Groups swap usage (app.anonymous-statistics_swap_usage)"
#   ],
#   [
#     "app.anonymous-statistics_disk_logical_io",
# ...
