# %% [markdown]
# # Examples
#
# Some examples of how to use the Netdata LLM Agent.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/andrewm4894/netdata-llm-agent/blob/main/notebooks/examples.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# if running in colab or need to install the package
# !pip install netdata-llm-agent

# agent needs some environment variables to run

# download the .env.example file into .env
# !wget https://raw.githubusercontent.com/andrewm4894/netdata-llm-agent/main/.env.example -O .env

# add you environment variables to .env
# print('add your environment variables to .env')

# or set the environment variables in your shell
# export OPENAI_API_KEY=your_api_key
# export ANTHROPIC_API_KEY=your_api_key

# %%
from IPython.display import display, Markdown

from netdata_llm_agent.agent import NetdataLLMAgent


def print_md(text):
    display(Markdown(text))


# list of netdata urls to interact with
netdata_urls = [
    'https://localhost:19999/',
    'https://london3.my-netdata.io/', 
    'https://bangalore.my-netdata.io/',
    'https://newyork.my-netdata.io/',
    'https://sanfrancisco.my-netdata.io/',
    'https://singapore.my-netdata.io/',
    'https://toronto.my-netdata.io/',
]

# create agent
agent = NetdataLLMAgent(netdata_urls, model='gpt-4o-mini')
# create agent using anthropic
# agent = NetdataLLMAgent(netdata_urls, model='claude-3-5-sonnet-20241022', platform='anthropic')
# create agent using ollama
# agent = NetdataLLMAgent(netdata_urls, model='llama3.1', platform='ollama')

# chat with the agent
agent.chat('How much disk space is on london?', verbose=True, no_print=False)
# Out:
# ================================ Human Message =================================
#
# How much disk space is on london?
# ================================== Ai Message ==================================
# Tool Calls:
#   get_charts (call_7j6IPWtLVu4OwvVFywmHmYIa)
#  Call ID: call_7j6IPWtLVu4OwvVFywmHmYIa
#   Args:
#     netdata_host_url: https://london3.my-netdata.io/
#     search_term: disk
# ================================= Tool Message =================================
# Name: get_charts
#
# [
#   [
#     "netdata.dbengine_query_pages_disk_load",
#     "Netdata Query Pages Loaded from Disk (netdata.dbengine_query_pages_disk_load)"
#   ],
#   [
#     "disk_space./",
#     "Disk Space Usage (disk_space./)"
#   ],
#   [
#     "disk_inodes./",
#     "Disk Files (inodes) Usage (disk_inodes./)"
#   ],
#   [
#     "disk_space./run",
#     "Disk Space Usage (disk_space./run)"
#   ],
#   [
#     "disk_inodes./run",
#     "Disk Files (inodes) Usage (disk_inodes./run)"
#   ],
#   [
#     "disk.vda",
#     "Disk I/O Bandwidth (disk.vda)"
#   ],
#   [
#     "disk_ext.vda",
#     "Amount of Discarded Data (disk_ext.vda)"
#   ],
#   [
#     "disk_ops.vda",
#     "Disk Completed I/O Operations (disk_ops.vda)"
#   ],
#   [
#     "disk_ext_ops.vda",
#     "Disk Completed Extended I/O Operations (disk_ext_ops.vda)"
#   ],
#   [
#     "disk_qops.vda",
#     "Disk Current I/O Operations (disk_qops.vda)"
#   ],
#   [
#     "disk_backlog.vda",
#     "Disk Backlog (disk_backlog.vda)"
#   ],
#   [
#     "disk_busy.vda",
#     "Disk Busy Time (disk_busy.vda)"
#   ],
#   [
#     "disk_util.vda",
#     "Disk Utilization Time (disk_util.vda)"
#   ],
#   [
#     "disk_mops.vda",
#     "Disk Merged Operations (disk_mops.vda)"
#   ],
#   [
#     "disk_ext_mops.vda",
#     "Disk Merged Discard Operations (disk_ext_mops.vda)"
#   ],
#   [
#     "disk_iotime.vda",
#     "Disk Total I/O Time (disk_iotime.vda)"
#   ],
#   [
#     "disk_ext_iotime.vda",
#     "Disk Total I/O Time for Extended Operations (disk_ext_iotime.vda)"
#   ],
#   [
#     "disk.config-2",
#     "Disk I/O Bandwidth (disk.config-2)"
#   ],
#   [
#     "disk_ext.config-2",
#     "Amount of Discarded Data (disk_ext.config-2)"
#   ],
#   [
#     "disk_ops.config-2",
#     "Disk Completed I/O Operations (disk_ops.config-2)"
#   ],
#   [
#     "disk_ext_ops.config-2",
#     "Disk Completed Extended I/O Operations (disk_ext_ops.config-2)"
#   ],
#   [
#     "disk_qops.config-2",
#     "Disk Current I/O Operations (disk_qops.config-2)"
#   ],
#   [
#     "disk_backlog.config-2",
#     "Disk Backlog (disk_backlog.config-2)"
#   ],
#   [
#     "disk_busy.config-2",
#     "Disk Busy Time (disk_busy.config-2)"
#   ],
#   [
#     "disk_util.config-2",
#     "Disk Utilization Time (disk_util.config-2)"
#   ],
#   [
#     "disk_mops.config-2",
#     "Disk Merged Operations (disk_mops.config-2)"
#   ],
#   [
#     "disk_ext_mops.config-2",
#     "Disk Merged Discard Operations (disk_ext_mops.config-2)"
#   ],
#   [
#     "disk_iotime.config-2",
#     "Disk Total I/O Time (disk_iotime.config-2)"
#   ],
#   [
#     "disk_ext_iotime.config-2",
#     "Disk Total I/O Time for Extended Operations (disk_ext_iotime.config-2)"
#   ],
#   [
#     "app.nfacct_plugin_disk_physical_io",
#     "Applications Groups disk physical IO (app.nfacct_plugin_disk_physical_io)"
#   ],
#   [
#     "app.nfacct_plugin_disk_logical_io",
#     "Applications Groups disk logical IO (app.nfacct_plugin_disk_logical_io)"
#   ],
#   [
#     "app.NETWORK-VIEWER_disk_physical_io",
#     "Applications Groups disk physical IO (app.NETWORK-VIEWER_disk_physical_io)"
#   ],
#   [
#     "app.NETWORK-VIEWER_disk_logical_io",
#     "Applications Groups disk logical IO (app.NETWORK-VIEWER_disk_logical_io)"
#   ],
#   [
#     "app.ebpf_plugin_disk_physical_io",
#     "Applications Groups disk physical IO (app.ebpf_plugin_disk_physical_io)"
#   ],
#   [
#     "app.ebpf_plugin_disk_logical_io",
#     "Applications Groups disk logical IO (app.ebpf_plugin_disk_logical_io)"
#   ],
#   [
#     "app.go_d_plugin_disk_physical_io",
#     "Applications Groups disk physical IO (app.go_d_plugin_disk_physical_io)"
#   ],
#   [
#     "app.go_d_plugin_disk_logical_io",
#     "Applications Groups disk logical IO (app.go_d_plugin_disk_logical_io)"
#   ],
#   [
#     "app.debugfs_plugin_disk_physical_io",
#     "Applications Groups disk physical IO (app.debugfs_plugin_disk_physical_io)"
#   ],
#   [
#     "app.debugfs_plugin_disk_logical_io",
#     "Applications Groups disk logical IO (app.debugfs_plugin_disk_logical_io)"
#   ],
#   [
#     "app.sd-jrnl_plugin_disk_physical_io",
#     "Applications Groups disk physical IO (app.sd-jrnl_plugin_disk_physical_io)"
#   ],
#   [
#     "app.sd-jrnl_plugin_disk_logical_io",
#     "Applications Groups disk logical IO (app.sd-jrnl_plugin_disk_logical_io)"
#   ],
#   [
#     "app.agetty_disk_physical_io",
#     "Applications Groups disk physical IO (app.agetty_disk_physical_io)"
#   ],
#   [
#     "app.agetty_disk_logical_io",
#     "Applications Groups disk logical IO (app.agetty_disk_logical_io)"
#   ],
#   [
#     "app.unattended-upgrades_disk_physical_io",
#     "Applications Groups disk physical IO (app.unattended-upgrades_disk_physical_io)"
#   ],
#   [
#     "app.unattended-upgrades_disk_logical_io",
#     "Applications Groups disk logical IO (app.unattended-upgrades_disk_logical_io)"
#   ],
#   [
#     "app.nscd_disk_physical_io",
#     "Applications Groups disk physical IO (app.nscd_disk_physical_io)"
#   ],
#   [
#     "app.nscd_disk_logical_io",
#     "Applications Groups disk logical IO (app.nscd_disk_logical_io)"
#   ],
#   [
#     "app.droplet-agent_disk_physical_io",
#     "Applications Groups disk physical IO (app.droplet-agent_disk_physical_io)"
#   ],
#   [
#     "app.droplet-agent_disk_logical_io",
#     "Applications Groups disk logical IO (app.droplet-agent_disk_logical_io)"
#   ],
#   [
#     "app.do-agent_disk_physical_io",
#     "Applications Groups disk physical IO (app.do-agent_disk_physical_io)"
#   ],
#   [
#     "app.do-agent_disk_logical_io",
#     "Applications Groups disk logical IO (app.do-agent_disk_logical_io)"
#   ],
#   [
#     "app.systemd_disk_physical_io",
#     "Applications Groups disk physical IO (app.systemd_disk_physical_io)"
#   ],
#   [
#     "app.systemd_disk_logical_io",
#     "Applications Groups disk logical IO (app.systemd_disk_logical_io)"
#   ],
#   [
#     "app.netdata_disk_physical_io",
#     "Applications Groups disk physical IO (app.netdata_disk_physical_io)"
#   ],
#   [
#     "app.netdata_disk_logical_io",
#     "Applications Groups disk logical IO (app.netdata_disk_logical_io)"
#   ],
#   [
#     "app.apps_plugin_disk_physical_io",
#     "Applications Groups disk physical IO (app.apps_plugin_disk_physical_io)"
#   ],
#   [
#     "app.apps_plugin_disk_logical_io",
#     "Applications Groups disk logical IO (app.apps_plugin_disk_logical_io)"
#   ],
#   [
#     "app.charts_d_plugin_disk_physical_io",
#     "Applications Groups disk physical IO (app.charts_d_plugin_disk_physical_io)"
#   ],
#   [
#     "app.charts_d_plugin_disk_logical_io",
#     "Applications Groups disk logical IO (app.charts_d_plugin_disk_logical_io)"
#   ],
#   [
#     "app.python_d_plugin_disk_physical_io",
#     "Applications Groups disk physical IO (app.python_d_plugin_disk_physical_io)"
#   ],
#   [
#     "app.python_d_plugin_disk_logical_io",
#     "Applications Groups disk logical IO (app.python_d_plugin_disk_logical_io)"
#   ],
#   [
#     "app.tc-qos-helper_disk_physical_io",
#     "Applications Groups disk physical IO (app.tc-qos-helper_disk_physical_io)"
#   ],
#   [
#     "app.tc-qos-helper_disk_logical_io",
#     "Applications Groups disk logical IO (app.tc-qos-helper_disk_logical_io)"
#   ],
#   [
#     "app.httpd_disk_physical_io",
#     "Applications Groups disk physical IO (app.httpd_disk_physical_io)"
#   ],
#   [
#     "app.httpd_disk_logical_io",
#     "Applications Groups disk logical IO (app.httpd_disk_logical_io)"
#   ],
#   [
#     "app.sql_disk_physical_io",
#     "Applications Groups disk physical IO (app.sql_disk_physical_io)"
#   ],
#   [
#     "app.sql_disk_logical_io",
#     "Applications Groups disk logical IO (app.sql_disk_logical_io)"
#   ],
#   [
#     "app.email_disk_physical_io",
#     "Applications Groups disk physical IO (app.email_disk_physical_io)"
#   ],
#   [
#     "app.email_disk_logical_io",
#     "Applications Groups disk logical IO (app.email_disk_logical_io)"
#   ],
#   [
#     "app.vpn_disk_physical_io",
#     "Applications Groups disk physical IO (app.vpn_disk_physical_io)"
#   ],
#   [
#     "app.vpn_disk_logical_io",
#     "Applications Groups disk logical IO (app.vpn_disk_logical_io)"
#   ],
#   [
#     "app.logs_disk_physical_io",
#     "Applications Groups disk physical IO (app.logs_disk_physical_io)"
#   ],
#   [
#     "app.logs_disk_logical_io",
#     "Applications Groups disk logical IO (app.logs_disk_logical_io)"
#   ],
#   [
#     "app.containers_disk_physical_io",
#     "Applications Groups disk physical IO (app.containers_disk_physical_io)"
#   ],
#   [
#     "app.containers_disk_logical_io",
#     "Applications Groups disk logical IO (app.containers_disk_logical_io)"
#   ],
#   [
#     "app.ssh_disk_physical_io",
#     "Applications Groups disk physical IO (app.ssh_disk_physical_io)"
#   ],
#   [
#     "app.ssh_disk_logical_io",
#     "Applications Groups disk logical IO (app.ssh_disk_logical_io)"
#   ],
#   [
#     "app.time_disk_physical_io",
#     "Applications Groups disk physical IO (app.time_disk_physical_io)"
#   ],
#   [
#     "app.time_disk_logical_io",
#     "Applications Groups disk logical IO (app.time_disk_logical_io)"
#   ],
#   [
#     "app.named_disk_physical_io",
#     "Applications Groups disk physical IO (app.named_disk_physical_io)"
#   ],
#   [
#     "app.named_disk_logical_io",
#     "Applications Groups disk logical IO (app.named_disk_logical_io)"
#   ],
#   [
#     "app.cron_disk_physical_io",
#     "Applications Groups disk physical IO (app.cron_disk_physical_io)"
#   ],
#   [
#     "app.cron_disk_logical_io",
#     "Applications Groups disk logical IO (app.cron_disk_logical_io)"
#   ],
#   [
#     "app.ksmd_disk_physical_io",
#     "Applications Groups disk physical IO (app.ksmd_disk_physical_io)"
#   ],
#   [
#     "app.ksmd_disk_logical_io",
#     "Applications Groups disk logical IO (app.ksmd_disk_logical_io)"
#   ],
#   [
#     "app.system_disk_physical_io",
#     "Applications Groups disk physical IO (app.system_disk_physical_io)"
#   ],
#   [
#     "app.system_disk_logical_io",
#     "Applications Groups disk logical IO (app.system_disk_logical_io)"
#   ],
#   [
#     "app.kernel_disk_physical_io",
#     "Applications Groups disk physical IO (app.kernel_disk_physical_io)"
#   ],
#   [
#     "app.kernel_disk_logical_io",
#     "Applications Groups disk logical IO (app.kernel_disk_logical_io)"
#   ],
#   [
#     "user.netdata_disk_physical_io",
#     "User Processes disk physical IO (user.netdata_disk_physical_io)"
#   ],
#   [
#     "user.netdata_disk_logical_io",
#     "User Processes disk logical IO (user.netdata_disk_logical_io)"
#   ],
#   [
#     "user.bind_disk_physical_io",
#     "User Processes disk physical IO (user.bind_disk_physical_io)"
#   ],
#   [
#     "user.bind_disk_logical_io",
#     "User Processes disk logical IO (user.bind_disk_logical_io)"
#   ],
#   [
#     "user.postfix_disk_physical_io",
#     "User Processes disk physical IO (user.postfix_disk_physical_io)"
#   ],
#   [
#     "user.postfix_disk_logical_io",
#     "User Processes disk logical IO (user.postfix_disk_logical_io)"
#   ],
#   [
#     "user.www-data_disk_physical_io",
#     "User Processes disk physical IO (user.www-data_disk_physical_io)"
#   ],
#   [
#     "user.www-data_disk_logical_io",
#     "User Processes disk logical IO (user.www-data_disk_logical_io)"
#   ],
#   [
#     "user.ntpsec_disk_physical_io",
#     "User Processes disk physical IO (user.ntpsec_disk_physical_io)"
#   ],
#   [
#     "user.ntpsec_disk_logical_io",
#     "User Processes disk logical IO (user.ntpsec_disk_logical_io)"
#   ],
#   [
#     "user.mysql_disk_physical_io",
#     "User Processes disk physical IO (user.mysql_disk_physical_io)"
#   ],
#   [
#     "user.mysql_disk_logical_io",
#     "User Processes disk logical IO (user.mysql_disk_logical_io)"
#   ],
#   [
#     "user.ulog_disk_physical_io",
#     "User Processes disk physical IO (user.ulog_disk_physical_io)"
#   ],
#   [
#     "user.ulog_disk_logical_io",
#     "User Processes disk logical IO (user.ulog_disk_logical_io)"
#   ],
#   [
#     "user.unscd_disk_physical_io",
#     "User Processes disk physical IO (user.unscd_disk_physical_io)"
#   ],
#   [
#     "user.unscd_disk_logical_io",
#     "User Processes disk logical IO (user.unscd_disk_logical_io)"
#   ],
#   [
#     "user.do-agent_disk_physical_io",
#     "User Processes disk physical IO (user.do-agent_disk_physical_io)"
#   ],
#   [
#     "user.do-agent_disk_logical_io",
#     "User Processes disk logical IO (user.do-agent_disk_logical_io)"
#   ],
#   [
#     "user.messagebus_disk_physical_io",
#     "User Processes disk physical IO (user.messagebus_disk_physical_io)"
#   ],
#   [
#     "user.messagebus_disk_logical_io",
#     "User Processes disk logical IO (user.messagebus_disk_logical_io)"
#   ],
#   [
#     "user.root_disk_physical_io",
#     "User Processes disk physical IO (user.root_disk_physical_io)"
#   ],
#   [
#     "user.root_disk_logical_io",
#     "User Processes disk logical IO (user.root_disk_logical_io)"
#   ],
#   [
#     "usergroup.netdata_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.netdata_disk_physical_io)"
#   ],
#   [
#     "usergroup.netdata_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.netdata_disk_logical_io)"
#   ],
#   [
#     "usergroup.bind_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.bind_disk_physical_io)"
#   ],
#   [
#     "usergroup.bind_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.bind_disk_logical_io)"
#   ],
#   [
#     "usergroup.systemd-journal_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.systemd-journal_disk_physical_io)"
#   ],
#   [
#     "usergroup.systemd-journal_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.systemd-journal_disk_logical_io)"
#   ],
#   [
#     "usergroup.postfix_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.postfix_disk_physical_io)"
#   ],
#   [
#     "usergroup.postfix_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.postfix_disk_logical_io)"
#   ],
#   [
#     "usergroup.www-data_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.www-data_disk_physical_io)"
#   ],
#   [
#     "usergroup.www-data_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.www-data_disk_logical_io)"
#   ],
#   [
#     "usergroup.ntpsec_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.ntpsec_disk_physical_io)"
#   ],
#   [
#     "usergroup.ntpsec_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.ntpsec_disk_logical_io)"
#   ],
#   [
#     "usergroup.mysql_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.mysql_disk_physical_io)"
#   ],
#   [
#     "usergroup.mysql_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.mysql_disk_logical_io)"
#   ],
#   [
#     "usergroup.ulog_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.ulog_disk_physical_io)"
#   ],
#   [
#     "usergroup.ulog_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.ulog_disk_logical_io)"
#   ],
#   [
#     "usergroup.unscd_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.unscd_disk_physical_io)"
#   ],
#   [
#     "usergroup.unscd_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.unscd_disk_logical_io)"
#   ],
#   [
#     "usergroup.do-agent_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.do-agent_disk_physical_io)"
#   ],
#   [
#     "usergroup.do-agent_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.do-agent_disk_logical_io)"
#   ],
#   [
#     "usergroup.messagebus_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.messagebus_disk_physical_io)"
#   ],
#   [
#     "usergroup.messagebus_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.messagebus_disk_logical_io)"
#   ],
#   [
#     "usergroup.root_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.root_disk_physical_io)"
#   ],
#   [
#     "usergroup.root_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.root_disk_logical_io)"
#   ],
#   [
#     "netdata.workers_time_diskspace",
#     "Netdata Workers Busy Time (100% = all workers busy) (netdata.workers_time_diskspace)"
#   ],
#   [
#     "netdata.workers_cpu_diskspace",
#     "Netdata Workers CPU Utilization (100% = all workers busy) (netdata.workers_cpu_diskspace)"
#   ],
#   [
#     "netdata.workers_jobs_by_type_diskspace",
#     "Netdata Workers Jobs Started by Type (netdata.workers_jobs_by_type_diskspace)"
#   ],
#   [
#     "netdata.workers_busy_time_by_type_diskspace",
#     "Netdata Workers Busy Time by Type (netdata.workers_busy_time_by_type_diskspace)"
#   ],
#   [
#     "netdata.workers_avg_time_by_type_diskspace",
#     "Netdata Workers Average Time by Type (netdata.workers_avg_time_by_type_diskspace)"
#   ],
#   [
#     "netdata.workers_spinlock_locks_diskspace",
#     "Netdata Spinlock Locks (netdata.workers_spinlock_locks_diskspace)"
#   ],
#   [
#     "netdata.workers_spinlock_spins_diskspace",
#     "Netdata Spinlock Spins (netdata.workers_spinlock_spins_diskspace)"
#   ],
#   [
#     "disk_await.vda",
#     "Average Completed I/O Operation Time (disk_await.vda)"
#   ],
#   [
#     "disk_ext_await.vda",
#     "Average Completed Extended I/O Operation Time (disk_ext_await.vda)"
#   ],
#   [
#     "disk_avgsz.vda",
#     "Average Completed I/O Operation Bandwidth (disk_avgsz.vda)"
#   ],
#   [
#     "disk_ext_avgsz.vda",
#     "Average Amount of Discarded Data (disk_ext_avgsz.vda)"
#   ],
#   [
#     "disk_svctm.vda",
#     "Average Service Time (disk_svctm.vda)"
#   ],
#   [
#     "disk_await.config-2",
#     "Average Completed I/O Operation Time (disk_await.config-2)"
#   ],
#   [
#     "disk_ext_await.config-2",
#     "Average Completed Extended I/O Operation Time (disk_ext_await.config-2)"
#   ],
#   [
#     "disk_avgsz.config-2",
#     "Average Completed I/O Operation Bandwidth (disk_avgsz.config-2)"
#   ],
#   [
#     "disk_ext_avgsz.config-2",
#     "Average Amount of Discarded Data (disk_ext_avgsz.config-2)"
#   ],
#   [
#     "disk_svctm.config-2",
#     "Average Service Time (disk_svctm.config-2)"
#   ],
#   [
#     "mysql_local.key_disk_ops",
#     "MyISAM Key Cache Disk Operations (mysql_local.key_disk_ops)"
#   ],
#   [
#     "user.sshd_disk_physical_io",
#     "User Processes disk physical IO (user.sshd_disk_physical_io)"
#   ],
#   [
#     "user.sshd_disk_logical_io",
#     "User Processes disk logical IO (user.sshd_disk_logical_io)"
#   ],
#   [
#     "usergroup.nogroup_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.nogroup_disk_physical_io)"
#   ],
#   [
#     "usergroup.nogroup_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.nogroup_disk_logical_io)"
#   ],
#   [
#     "usergroup.postdrop_disk_physical_io",
#     "User Group Processes disk physical IO (usergroup.postdrop_disk_physical_io)"
#   ],
#   [
#     "usergroup.postdrop_disk_logical_io",
#     "User Group Processes disk logical IO (usergroup.postdrop_disk_logical_io)"
#   ],
#   [
#     "user._apt_disk_physical_io",
#     "User Processes disk physical IO (user._apt_disk_physical_io)"
#   ],
#   [
#     "user._apt_disk_logical_io",
#     "User Processes disk logical IO (user._apt_disk_logical_io)"
#   ],
#   [
#     "app.backup_disk_physical_io",
#     "Applications Groups disk physical IO (app.backup_disk_physical_io)"
#   ],
#   [
#     "app.backup_disk_logical_io",
#     "Applications Groups disk logical IO (app.backup_disk_logical_io)"
#   ],
#   [
#     "app.alarm-notify_disk_physical_io",
#     "Applications Groups disk physical IO (app.alarm-notify_disk_physical_io)"
#   ],
#   [
#     "app.alarm-notify_disk_logical_io",
#     "Applications Groups disk logical IO (app.alarm-notify_disk_logical_io)"
#   ],
#   [
#     "app.apt_systemd_daily_disk_physical_io",
#     "Applications Groups disk physical IO (app.apt_systemd_daily_disk_physical_io)"
#   ],
#   [
#     "app.apt_systemd_daily_disk_logical_io",
#     "Applications Groups disk logical IO (app.apt_systemd_daily_disk_logical_io)"
#   ],
#   [
#     "app.certbot_disk_physical_io",
#     "Applications Groups disk physical IO (app.certbot_disk_physical_io)"
#   ],
#   [
#     "app.certbot_disk_logical_io",
#     "Applications Groups disk logical IO (app.certbot_disk_logical_io)"
#   ]
# ]
# ================================== Ai Message ==================================
# Tool Calls:
#   get_chart_data (call_fdvYLm2ntI6W2VwwMNaLPavO)
#  Call ID: call_fdvYLm2ntI6W2VwwMNaLPavO
#   Args:
#     netdata_host_url: https://london3.my-netdata.io/
#     chart: disk_space./
# ================================= Tool Message =================================
# Name: get_chart_data
#
#     avail     used  reserved for root
# 112.77004 38.23786           6.435379
# 112.76998 38.23793           6.435379
# 112.76992 38.23798           6.435379
# 112.76983 38.23807           6.435379
# 112.76977 38.23814           6.435379
# 112.76972 38.23818           6.435379
# 112.76966 38.23825           6.435379
# 112.76953 38.23837           6.435379
# 112.76926 38.23865           6.435379
# 112.76921 38.23869           6.435379
# 112.76912 38.23878           6.435379
# 112.76907 38.23883           6.435379
# ================================== Ai Message ==================================
#
# The disk space on the London Netdata server is as follows:
#
# - **Available Disk Space:** Approximately **112.77 GiB**
# - **Used Disk Space:** Approximately **38.24 GiB**
# - **Reserved for Root:** Approximately **6.44 GiB**
#
# Let me know if you need more information!
# ================================== Ai Message ==================================
#
# The disk space on the London Netdata server is as follows:
#
# - **Available Disk Space:** Approximately **112.77 GiB**
# - **Used Disk Space:** Approximately **38.24 GiB**
# - **Reserved for Root:** Approximately **6.44 GiB**
#
# Let me know if you need more information!

# %%
# chat with agent
msg = 'What hosts are reachable from the london node?'
print_md(agent.chat(msg, return_last=True))
# Out:
# The following hosts are reachable from the London node:
#
# 1. **registry.my-netdata.io** - 0 hops
# 2. **toronto.netdata.rocks** - 6 hops
# 3. **sanfrancisco** - 6 hops
# 4. **frankfurt.netdata.rocks** - 4 hops
# 5. **newyork.netdata.rocks** - 4 hops
# 6. **singapore.netdata.rocks** - 6 hops
# 7. **d1.firehol.org** - 4 hops
# 8. **bangalore** - 3 hops
#
# The host **cdn77** is not reachable.

# %%
msg = 'What is my CPU utilization recently on london?'
print_md(agent.chat(msg, return_last=True))
# Out:
# Over the past hour, the CPU utilization on the London server (`https://london3.my-netdata.io/`) has varied across different components. Here's a summary of CPU usage in percentages for key components:
#
# - **User** CPU utilization has fluctuated, with an average around 4.3%.
# - **System** CPU utilization has averaged around 1.8%.
# - **I/O Wait** has been minimal, averaging around 0.02%.
# - **SoftIRQ** has hovered around 0.64%.
# - **Steal** has been very low, averaging around 0.09%.
#
# These values indicate a relatively low load on the system, with user processes consuming the majority of CPU resources. If you need more detailed analysis or further breakdowns, feel free to ask!

# %%
msg = 'What apps are using most cpu on new york over the last 15 minutes?'
print_md(agent.chat(msg, return_last=True))
# Out:
# Over the last 15 minutes, here are the CPU utilization metrics for several applications on the New York node:
#
# 1. **app.go_d_plugin_cpu_utilization**:
#    - Average User CPU: 0.58
#    - Average System CPU: 0.28
#
# 2. **app.ebpf_plugin_cpu_utilization**:
#    - Average User CPU: 0.00
#    - Average System CPU: 0.05
#
# 3. **app.NETWORK-VIEWER_cpu_utilization**:
#    - Average User CPU: 0.00
#    - Average System CPU: 0.00
#
# 4. **app.nfacct_plugin_cpu_utilization**:
#    - Average User CPU: 0.00
#    - Average System CPU: 0.00
#
# 5. **app.systemd_cpu_utilization**:
#    - Average User CPU: 0.51
#    - Average System CPU: 0.02
#
# 6. **app.netdata_cpu_utilization**:
#    - Average User CPU: 0.49
#    - Average System CPU: 0.42
#
# 7. **app.httpd_cpu_utilization**:
#    - Average User CPU: 9.00 (notable peak)
#    - Average System CPU: 2.07
#
# 8. **app.vpn_cpu_utilization**:
#    - Average User CPU: 0.00
#    - Average System CPU: 0.09
#
# 9. **app.logs_cpu_utilization**:
#    - Average User CPU: 0.00
#    - Average System CPU: 0.09
#
# 10. **app.nfs_cpu_utilization**:
#     - Average User CPU: 0.00
#     - Average System CPU: 0.00
#
# ### Notable Observations:
# - The **app.httpd_cpu_utilization** has the highest CPU utilization, particularly in User CPU usage.
# - Several applications show negligible or zero CPU utilization over this period.
#
# Please let me know if you need more specific information or other charts!

# %%
msg = 'What users are using most cpu on sanfransicso the last hour?'
print_md(agent.chat(msg, return_last=True))
# Out:
# Here are the user processes' CPU utilization percentages over the last hour in San Francisco. The values represent the average utilization for each data point taken at intervals within the hour:
#
# - User CPU Utilization: Averages between roughly 8.5% to 10.5%.
# - System CPU Utilization: Ranges between approximately 2.1% to 3.0%.
#
# Note that there are some missing data points. However, overall trends indicate that user processes are consuming significantly more CPU than system processes. If you need a specific breakdown by users, further analysis can be performed based on user-specific data if available.

# %%
msg = 'What specific users are using most cpu on bangalore?'
print_md(agent.chat(msg, return_last=True))
# Out:
# On the Bangalore node, the current CPU utilization by specific users is as follows:
#
# 1. **User `netdata`**
#    - User CPU Utilization: 12.000247%
#    - System CPU Utilization: 4.6673811%
#
# 2. **User `root`**
#    - User CPU Utilization: 2.0012143%
#    - System CPU Utilization: 3.3342598%
#    - Total CPU Utilization: 5.3354741%
#
# 3. **User `www-data`**
#    - User CPU Utilization: 0%
#    - System CPU Utilization: 0%
#    - Total CPU Utilization: 0%
#
# 4. **User `Debian-exim`**
#    - User CPU Utilization: 0%
#    - System CPU Utilization: 0%
#    - Total CPU Utilization: 0%
#
# 5. **User `unbound`**
#    - User CPU Utilization: 0%
#    - System CPU Utilization: 0%
#    - Total CPU Utilization: 0%
#
# 6. **User `daemon`**
#    - User CPU Utilization: 0%
#    - System CPU Utilization: 0%
#    - Total CPU Utilization: 0%
#
# 7. **User `logind`** (in the context of users, like sessions)
#    - Online Users: 0
#    - Active Users: 0
#
# Based on the current data, the user `netdata` is utilizing the highest CPU among the users, followed by `root`. Other users are not consuming any CPU resources at this time.

# %%
msg = 'what is the ram usage like on bangalore node?'
print_md(agent.chat(msg, return_last=True))
# Out:
# The RAM usage on the Bangalore node is as follows (in MB):
#
# - **Free RAM**: varies between approximately 157 MB to 170 MB.
# - **Used RAM**: hovers around 951 MB to 964 MB.
# - **Cached**: remains steady at approximately 717 MB.
# - **Buffers**: remains steady at approximately 127 MB.
#
# These values give a snapshot of the current RAM utilization.

# %%
msg = 'How are the mysql metrics looking on the london?'
print_md(agent.chat(msg, return_last=True))
# Out:
# Here's a quick summary of the current MySQL metrics for the London host:
#
# 1. **CPU Utilization**:
#    - User CPU utilization fluctuates between approximately 0.28 to 0.48.
#    - System CPU utilization remains much lower in comparison, occasionally spiking.
#
# 2. **Memory Usage**:
#    - Unfortunately, there was an SSL error while attempting to retrieve memory usage data, preventing a complete analysis. It may be necessary to check the connection or the server's SSL configuration.
#
# 3. **Connections**:
#    - The data indicates no open or aborted connections for the checked interval.
#
# 4. **Queries**:
#    - Both regular and slow queries appear steady, maintaining a rate of approximately six queries/sec, with no slow queries detected in the last few minutes.
#
# If you have any specific metrics you'd like me to investigate or need further assistance, feel free to ask!

# %%
msg = 'any active alarms on toronto?'
print_md(agent.chat(msg, return_last=True))
# Out:
# There are currently two active alarms on the Toronto Netdata instance:
#
# 1. **Alarm Name:** 10min_qos_packet_drops
#    - **Chart:** `tc.eth0_dropped`
#    - **Status:** WARNING
#    - **Value:** 2 packets
#    - **Info:** Dropped packets in the last 5 minutes
#    - **Summary:** QOS packet drops
#
# 2. **Alarm Name:** 10min_qos_packet_drops
#    - **Chart:** `tc.eth0-ifb_dropped`
#    - **Status:** WARNING
#    - **Value:** 4 packets
#    - **Info:** Dropped packets in the last 5 minutes
#    - **Summary:** QOS packet drops
#
# Both alarms indicate that there are packet drops occurring in the specified time frame.

# %%
msg = 'what do the alarms mean? should i be worried?'
print_md(agent.chat(msg, return_last=True, continue_chat=True))
# Out:
# The active alarms indicate that there are packets being dropped in the network interface cards monitored by the respective charts. Here's a breakdown of what this means:
#
# 1. **Packet Drops**: Packet drops occur when a device cannot process incoming packets fast enough. This can be due to several reasons such as high traffic, insufficient resources (CPU, memory), network congestion, or hardware issues.
#
# 2. **Implications**:
#    - If your application relies on real-time communication (like VoIP, online gaming, or streaming services), packet drops can lead to performance issues like lag, interruptions, or lower quality service.
#    - If this is happening on a critical service or application, it may affect the availability or reliability of your services.
#
# 3. **Should You Be Worried?**:
#    - **Short Intervals**: If this is a transient issue (i.e., it happens for a short time and is followed by no further drops), it may not be a major concern.
#    - **Persisting Issues**: If these alarms persist, you should investigate the cause. It may require tuning your network settings, allocating more resources, or checking for hardware issues.
#
# ### Recommended Actions:
# - Monitor the charts for trends in packet drops.
# - Check the health of your network equipment (routers, switches).
# - Analyze traffic patterns to see if there are spikes in usage that coincide with the packet drops.
# - Consider setting up additional alarms or performance metrics to get alerted if the situation worsens.
#
# In summary, while packet drops are a cause for concern, especially if they’re consistent, they are not necessarily an immediate crisis. Proactive monitoring and analysis will help ensure that any potential issues are managed swiftly.

# %%
msg = 'How are the nginx metrics looking on the london node over he last couple of hours?'
print_md(agent.chat(msg, return_last=True))
# Out:
# Here's a summary of the Nginx metrics on the London node over the last couple of hours:
#
# 1. **Connections**: The average number of active connections is around 151, with fluctuations between 135 and 167 observed periodically.
#
# 2. **Requests**: Approximately 10–11 requests were handled on average per data point during the period.
#
# 3. **Accepted and Handled Connections**: There's a steady rate of accepted and handled connections, which appears to hover slightly under 1 connection per data interval on average.
#
# 4. **Connection Status**:
#    - Most connections are idle, ranging from around 128 to 166 on average.
#    - The number of active writing connections is generally stable at about 1.
#
# These metrics indicate relatively steady activity on the Nginx server in London with no significant variations observed in the last couple of hours. If you need further details or have specific questions about these metrics, feel free to ask!
